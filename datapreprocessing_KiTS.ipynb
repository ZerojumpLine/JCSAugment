# %%
datadownloadpath = './datadownload/KiTS/'
datasavepath = './datapreprocessed/KiTS/'

# %%
import glob
import SimpleITK as sitk
import numpy as np
from scipy.ndimage import label, binary_fill_holes
import os

# %%
if os.path.exists(datasavepath + 'Image') == False:
    os.mkdir(datasavepath + 'Image')
    os.mkdir(datasavepath + 'Label')
    os.mkdir(datasavepath + 'processed')
    os.mkdir(datasavepath + 'mask')

# %%
# helper functions copy pasted
def resample_by_res(mov_img_obj, new_spacing, interpolator = sitk.sitkLinear, logging = True):
    resample = sitk.ResampleImageFilter()
    resample.SetInterpolator(interpolator)
    resample.SetOutputDirection(mov_img_obj.GetDirection())
    # fix the direction.
#     resample.SetOutputDirection(tuple(np.abs(mov_img_obj.GetDirection())))
    resample.SetOutputOrigin(mov_img_obj.GetOrigin())
    resample.SetUseNearestNeighborExtrapolator(True)
    mov_spacing = mov_img_obj.GetSpacing()

    resample.SetOutputSpacing(new_spacing)
    RES_COE = np.array(mov_spacing) * 1.0 / np.array(new_spacing)
    new_size = np.array(mov_img_obj.GetSize()) *  RES_COE 

    resample.SetSize( [int(sz+1) for sz in new_size] )
    if logging:
        print("Spacing: {} -> {}".format(mov_spacing, new_spacing))
        print("Size {} -> {}".format( mov_img_obj.GetSize(), new_size ))

    return resample.Execute(mov_img_obj)

def resample_lb_by_res(mov_lb_obj, new_spacing, interpolator = sitk.sitkLinear, ref_img = None, logging = True):
    src_mat = sitk.GetArrayFromImage(mov_lb_obj)
    lbvs = np.unique(src_mat)
    if logging:
        print("Label values: {}".format(lbvs))
    for idx, lbv in enumerate(lbvs):
        _src_curr_mat = np.float32(src_mat == lbv) 
        _src_curr_obj = sitk.GetImageFromArray(_src_curr_mat)
        _src_curr_obj.CopyInformation(mov_lb_obj)
        _tar_curr_obj = resample_by_res( _src_curr_obj, new_spacing, interpolator, logging )
        _tar_curr_mat = np.rint(sitk.GetArrayFromImage(_tar_curr_obj)) * lbv
        if idx == 0:
            out_vol = _tar_curr_mat
        else:
            out_vol[_tar_curr_mat == lbv] = lbv
    out_obj = sitk.GetImageFromArray(out_vol)
    out_obj.SetSpacing( _tar_curr_obj.GetSpacing() )
    if ref_img != None:
        out_obj.CopyInformation(ref_img)
    return out_obj

def remove_all_but_the_largest_connected_component(image: np.ndarray, for_which_classes: list, volume_per_voxel: float,
                                                   minimum_valid_object_size: dict = None):
    """
    removes all but the largest connected component, individually for each class
    :param image:
    :param for_which_classes: can be None. Should be list of int. Can also be something like [(1, 2), 2, 4].
    Here (1, 2) will be treated as a joint region, not individual classes (example LiTS here we can use (1, 2)
    to use all foreground classes together)
    :param minimum_valid_object_size: Only objects larger than minimum_valid_object_size will be removed. Keys in
    minimum_valid_object_size must match entries in for_which_classes
    :return:
    """
    if for_which_classes is None:
        for_which_classes = np.unique(image)
        for_which_classes = for_which_classes[for_which_classes > 0]

    assert 0 not in for_which_classes, "cannot remove background"
    largest_removed = {}
    kept_size = {}
    for c in for_which_classes:
        if isinstance(c, (list, tuple)):
            c = tuple(c)  # otherwise it cant be used as key in the dict
            mask = np.zeros_like(image, dtype=bool)
            for cl in c:
                mask[image == cl] = True
        else:
            mask = image == c
        # get labelmap and number of objects
        lmap, num_objects = label(mask.astype(int))

        # collect object sizes
        object_sizes = {}
        for object_id in range(1, num_objects + 1):
            object_sizes[object_id] = (lmap == object_id).sum() * volume_per_voxel

        largest_removed[c] = None
        kept_size[c] = None

        if num_objects > 0:
            # we always keep the largest object. We could also consider removing the largest object if it is smaller
            # than minimum_valid_object_size in the future but we don't do that now.
            maximum_size = max(object_sizes.values())
            kept_size[c] = maximum_size

            for object_id in range(1, num_objects + 1):
                # we only remove objects that are not the largest
                if object_sizes[object_id] != maximum_size:
                    # we only remove objects that are smaller than minimum_valid_object_size
                    remove = True
                    if minimum_valid_object_size is not None:
                        remove = object_sizes[object_id] < minimum_valid_object_size[c]
                    if remove:
                        image[(lmap == object_id) & mask] = 0
                        if largest_removed[c] is None:
                            largest_removed[c] = object_sizes[object_id]
                        else:
                            largest_removed[c] = max(largest_removed[c], object_sizes[object_id])
    return image, largest_removed, kept_size

# %%
IMG_FOLDER = datadownloadpath
SEG_FOLDER = datadownloadpath
imgs = glob.glob(IMG_FOLDER + "case_*/imaging.nii.gz")
imgs = [ fid for fid in sorted(imgs) ]
segs = [ fid for fid in sorted(glob.glob(SEG_FOLDER + "case_*/segmentation.nii.gz")) ]

pids = [pid.split("_")[-1].split("/")[0] for pid in imgs]

# %%
imgs
# Out:
# ['./datadownload/KiTS/case_00000/imaging.nii.gz',
#  './datadownload/KiTS/case_00001/imaging.nii.gz',
#  './datadownload/KiTS/case_00002/imaging.nii.gz',
#  './datadownload/KiTS/case_00003/imaging.nii.gz',
#  './datadownload/KiTS/case_00004/imaging.nii.gz',
#  './datadownload/KiTS/case_00005/imaging.nii.gz',
#  './datadownload/KiTS/case_00006/imaging.nii.gz',
#  './datadownload/KiTS/case_00007/imaging.nii.gz',
#  './datadownload/KiTS/case_00008/imaging.nii.gz',
#  './datadownload/KiTS/case_00009/imaging.nii.gz',
#  './datadownload/KiTS/case_00010/imaging.nii.gz',
#  './datadownload/KiTS/case_00011/imaging.nii.gz',
#  './datadownload/KiTS/case_00012/imaging.nii.gz',
#  './datadownload/KiTS/case_00013/imaging.nii.gz',
#  './datadownload/KiTS/case_00014/imaging.nii.gz',
#  './datadownload/KiTS/case_00015/imaging.nii.gz',
#  './datadownload/KiTS/case_00016/imaging.nii.gz',
#  './datadownload/KiTS/case_00017/imaging.nii.gz',
#  './datadownload/KiTS/case_00018/imaging.nii.gz',
#  './datadownload/KiTS/case_00019/imaging.nii.gz',
#  './datadownload/KiTS/case_00020/imaging.nii.gz',
#  './datadownload/KiTS/case_00021/imaging.nii.gz',
#  './datadownload/KiTS/case_00022/imaging.nii.gz',
#  './datadownload/KiTS/case_00023/imaging.nii.gz',
#  './datadownload/KiTS/case_00024/imaging.nii.gz',
#  './datadownload/KiTS/case_00025/imaging.nii.gz',
#  './datadownload/KiTS/case_00026/imaging.nii.gz',
#  './datadownload/KiTS/case_00027/imaging.nii.gz',
#  './datadownload/KiTS/case_00028/imaging.nii.gz',
#  './datadownload/KiTS/case_00029/imaging.nii.gz',
#  './datadownload/KiTS/case_00030/imaging.nii.gz',
#  './datadownload/KiTS/case_00031/imaging.nii.gz',
#  './datadownload/KiTS/case_00032/imaging.nii.gz',
#  './datadownload/KiTS/case_00033/imaging.nii.gz',
#  './datadownload/KiTS/case_00034/imaging.nii.gz',
#  './datadownload/KiTS/case_00035/imaging.nii.gz',
#  './datadownload/KiTS/case_00036/imaging.nii.gz',
#  './datadownload/KiTS/case_00037/imaging.nii.gz',
#  './datadownload/KiTS/case_00038/imaging.nii.gz',
#  './datadownload/KiTS/case_00039/imaging.nii.gz',
#  './datadownload/KiTS/case_00040/imaging.nii.gz',
#  './datadownload/KiTS/case_00041/imaging.nii.gz',
#  './datadownload/KiTS/case_00042/imaging.nii.gz',
#  './datadownload/KiTS/case_00043/imaging.nii.gz',
#  './datadownload/KiTS/case_00044/imaging.nii.gz',
#  './datadownload/KiTS/case_00045/imaging.nii.gz',
#  './datadownload/KiTS/case_00046/imaging.nii.gz',
#  './datadownload/KiTS/case_00047/imaging.nii.gz',
#  './datadownload/KiTS/case_00048/imaging.nii.gz',
#  './datadownload/KiTS/case_00049/imaging.nii.gz',
#  './datadownload/KiTS/case_00050/imaging.nii.gz',
#  './datadownload/KiTS/case_00051/imaging.nii.gz',
#  './datadownload/KiTS/case_00052/imaging.nii.gz',
#  './datadownload/KiTS/case_00053/imaging.nii.gz',
#  './datadownload/KiTS/case_00054/imaging.nii.gz',
#  './datadownload/KiTS/case_00055/imaging.nii.gz',
#  './datadownload/KiTS/case_00056/imaging.nii.gz',
#  './datadownload/KiTS/case_00057/imaging.nii.gz',
#  './datadownload/KiTS/case_00058/imaging.nii.gz',
#  './datadownload/KiTS/case_00059/imaging.nii.gz',
#  './datadownload/KiTS/case_00060/imaging.nii.gz',
#  './datadownload/KiTS/case_00061/imaging.nii.gz',
#  './datadownload/KiTS/case_00062/imaging.nii.gz',
#  './datadownload/KiTS/case_00063/imaging.nii.gz',
#  './datadownload/KiTS/case_00064/imaging.nii.gz',
#  './datadownload/KiTS/case_00065/imaging.nii.gz',
#  './datadownload/KiTS/case_00066/imaging.nii.gz',
#  './datadownload/KiTS/case_00067/imaging.nii.gz',
#  './datadownload/KiTS/case_00068/imaging.nii.gz',
#  './datadownload/KiTS/case_00069/imaging.nii.gz',
#  './datadownload/KiTS/case_00070/imaging.nii.gz',
#  './datadownload/KiTS/case_00071/imaging.nii.gz',
#  './datadownload/KiTS/case_00072/imaging.nii.gz',
#  './datadownload/KiTS/case_00073/imaging.nii.gz',
#  './datadownload/KiTS/case_00074/imaging.nii.gz',
#  './datadownload/KiTS/case_00075/imaging.nii.gz',
#  './datadownload/KiTS/case_00076/imaging.nii.gz',
#  './datadownload/KiTS/case_00077/imaging.nii.gz',
#  './datadownload/KiTS/case_00078/imaging.nii.gz',
#  './datadownload/KiTS/case_00079/imaging.nii.gz',
#  './datadownload/KiTS/case_00080/imaging.nii.gz',
#  './datadownload/KiTS/case_00081/imaging.nii.gz',
#  './datadownload/KiTS/case_00082/imaging.nii.gz',
#  './datadownload/KiTS/case_00083/imaging.nii.gz',
#  './datadownload/KiTS/case_00084/imaging.nii.gz',
#  './datadownload/KiTS/case_00085/imaging.nii.gz',
#  './datadownload/KiTS/case_00086/imaging.nii.gz',
#  './datadownload/KiTS/case_00087/imaging.nii.gz',
#  './datadownload/KiTS/case_00088/imaging.nii.gz',
#  './datadownload/KiTS/case_00089/imaging.nii.gz',
#  './datadownload/KiTS/case_00090/imaging.nii.gz',
#  './datadownload/KiTS/case_00091/imaging.nii.gz',
#  './datadownload/KiTS/case_00092/imaging.nii.gz',
#  './datadownload/KiTS/case_00093/imaging.nii.gz',
#  './datadownload/KiTS/case_00094/imaging.nii.gz',
#  './datadownload/KiTS/case_00095/imaging.nii.gz',
#  './datadownload/KiTS/case_00096/imaging.nii.gz',
#  './datadownload/KiTS/case_00097/imaging.nii.gz',
#  './datadownload/KiTS/case_00098/imaging.nii.gz',
#  './datadownload/KiTS/case_00099/imaging.nii.gz',
#  './datadownload/KiTS/case_00100/imaging.nii.gz',
#  './datadownload/KiTS/case_00101/imaging.nii.gz',
#  './datadownload/KiTS/case_00102/imaging.nii.gz',
#  './datadownload/KiTS/case_00103/imaging.nii.gz',
#  './datadownload/KiTS/case_00104/imaging.nii.gz',
#  './datadownload/KiTS/case_00105/imaging.nii.gz',
#  './datadownload/KiTS/case_00106/imaging.nii.gz',
#  './datadownload/KiTS/case_00107/imaging.nii.gz',
#  './datadownload/KiTS/case_00108/imaging.nii.gz',
#  './datadownload/KiTS/case_00109/imaging.nii.gz',
#  './datadownload/KiTS/case_00110/imaging.nii.gz',
#  './datadownload/KiTS/case_00111/imaging.nii.gz',
#  './datadownload/KiTS/case_00112/imaging.nii.gz',
#  './datadownload/KiTS/case_00113/imaging.nii.gz',
#  './datadownload/KiTS/case_00114/imaging.nii.gz',
#  './datadownload/KiTS/case_00115/imaging.nii.gz',
#  './datadownload/KiTS/case_00116/imaging.nii.gz',
#  './datadownload/KiTS/case_00117/imaging.nii.gz',
#  './datadownload/KiTS/case_00118/imaging.nii.gz',
#  './datadownload/KiTS/case_00119/imaging.nii.gz',
#  './datadownload/KiTS/case_00120/imaging.nii.gz',
#  './datadownload/KiTS/case_00121/imaging.nii.gz',
#  './datadownload/KiTS/case_00122/imaging.nii.gz',
#  './datadownload/KiTS/case_00123/imaging.nii.gz',
#  './datadownload/KiTS/case_00124/imaging.nii.gz',
#  './datadownload/KiTS/case_00125/imaging.nii.gz',
#  './datadownload/KiTS/case_00126/imaging.nii.gz',
#  './datadownload/KiTS/case_00127/imaging.nii.gz',
#  './datadownload/KiTS/case_00128/imaging.nii.gz',
#  './datadownload/KiTS/case_00129/imaging.nii.gz',
#  './datadownload/KiTS/case_00130/imaging.nii.gz',
#  './datadownload/KiTS/case_00131/imaging.nii.gz',
#  './datadownload/KiTS/case_00132/imaging.nii.gz',
#  './datadownload/KiTS/case_00133/imaging.nii.gz',
#  './datadownload/KiTS/case_00134/imaging.nii.gz',
#  './datadownload/KiTS/case_00135/imaging.nii.gz',
#  './datadownload/KiTS/case_00136/imaging.nii.gz',
#  './datadownload/KiTS/case_00137/imaging.nii.gz',
#  './datadownload/KiTS/case_00138/imaging.nii.gz',
#  './datadownload/KiTS/case_00139/imaging.nii.gz',
#  './datadownload/KiTS/case_00140/imaging.nii.gz',
#  './datadownload/KiTS/case_00141/imaging.nii.gz',
#  './datadownload/KiTS/case_00142/imaging.nii.gz',
#  './datadownload/KiTS/case_00143/imaging.nii.gz',
#  './datadownload/KiTS/case_00144/imaging.nii.gz',
#  './datadownload/KiTS/case_00145/imaging.nii.gz',
#  './datadownload/KiTS/case_00146/imaging.nii.gz',
#  './datadownload/KiTS/case_00147/imaging.nii.gz',
#  './datadownload/KiTS/case_00148/imaging.nii.gz',
#  './datadownload/KiTS/case_00149/imaging.nii.gz',
#  './datadownload/KiTS/case_00150/imaging.nii.gz',
#  './datadownload/KiTS/case_00151/imaging.nii.gz',
#  './datadownload/KiTS/case_00152/imaging.nii.gz',
#  './datadownload/KiTS/case_00153/imaging.nii.gz',
#  './datadownload/KiTS/case_00154/imaging.nii.gz',
#  './datadownload/KiTS/case_00155/imaging.nii.gz',
#  './datadownload/KiTS/case_00156/imaging.nii.gz',
#  './datadownload/KiTS/case_00157/imaging.nii.gz',
#  './datadownload/KiTS/case_00158/imaging.nii.gz',
#  './datadownload/KiTS/case_00159/imaging.nii.gz',
#  './datadownload/KiTS/case_00160/imaging.nii.gz',
#  './datadownload/KiTS/case_00161/imaging.nii.gz',
#  './datadownload/KiTS/case_00162/imaging.nii.gz',
#  './datadownload/KiTS/case_00163/imaging.nii.gz',
#  './datadownload/KiTS/case_00164/imaging.nii.gz',
#  './datadownload/KiTS/case_00165/imaging.nii.gz',
#  './datadownload/KiTS/case_00166/imaging.nii.gz',
#  './datadownload/KiTS/case_00167/imaging.nii.gz',
#  './datadownload/KiTS/case_00168/imaging.nii.gz',
#  './datadownload/KiTS/case_00169/imaging.nii.gz',
#  './datadownload/KiTS/case_00170/imaging.nii.gz',
#  './datadownload/KiTS/case_00171/imaging.nii.gz',
#  './datadownload/KiTS/case_00172/imaging.nii.gz',
#  './datadownload/KiTS/case_00173/imaging.nii.gz',
#  './datadownload/KiTS/case_00174/imaging.nii.gz',
#  './datadownload/KiTS/case_00175/imaging.nii.gz',
#  './datadownload/KiTS/case_00176/imaging.nii.gz',
#  './datadownload/KiTS/case_00177/imaging.nii.gz',
#  './datadownload/KiTS/case_00178/imaging.nii.gz',
#  './datadownload/KiTS/case_00179/imaging.nii.gz',
#  './datadownload/KiTS/case_00180/imaging.nii.gz',
#  './datadownload/KiTS/case_00181/imaging.nii.gz',
#  './datadownload/KiTS/case_00182/imaging.nii.gz',
#  './datadownload/KiTS/case_00183/imaging.nii.gz',
#  './datadownload/KiTS/case_00184/imaging.nii.gz',
#  './datadownload/KiTS/case_00185/imaging.nii.gz',
#  './datadownload/KiTS/case_00186/imaging.nii.gz',
#  './datadownload/KiTS/case_00187/imaging.nii.gz',
#  './datadownload/KiTS/case_00188/imaging.nii.gz',
#  './datadownload/KiTS/case_00189/imaging.nii.gz',
#  './datadownload/KiTS/case_00190/imaging.nii.gz',
#  './datadownload/KiTS/case_00191/imaging.nii.gz',
#  './datadownload/KiTS/case_00192/imaging.nii.gz',
#  './datadownload/KiTS/case_00193/imaging.nii.gz',
#  './datadownload/KiTS/case_00194/imaging.nii.gz',
#  './datadownload/KiTS/case_00195/imaging.nii.gz',
#  './datadownload/KiTS/case_00196/imaging.nii.gz',
#  './datadownload/KiTS/case_00197/imaging.nii.gz',
#  './datadownload/KiTS/case_00198/imaging.nii.gz',
#  './datadownload/KiTS/case_00199/imaging.nii.gz',
#  './datadownload/KiTS/case_00200/imaging.nii.gz',
#  './datadownload/KiTS/case_00201/imaging.nii.gz',
#  './datadownload/KiTS/case_00202/imaging.nii.gz',
#  './datadownload/KiTS/case_00203/imaging.nii.gz',
#  './datadownload/KiTS/case_00204/imaging.nii.gz',
#  './datadownload/KiTS/case_00205/imaging.nii.gz',
#  './datadownload/KiTS/case_00206/imaging.nii.gz',
#  './datadownload/KiTS/case_00207/imaging.nii.gz',
#  './datadownload/KiTS/case_00208/imaging.nii.gz',
#  './datadownload/KiTS/case_00209/imaging.nii.gz',
#  './datadownload/KiTS/case_00210/imaging.nii.gz',
#  './datadownload/KiTS/case_00211/imaging.nii.gz',
#  './datadownload/KiTS/case_00212/imaging.nii.gz',
#  './datadownload/KiTS/case_00213/imaging.nii.gz',
#  './datadownload/KiTS/case_00214/imaging.nii.gz',
#  './datadownload/KiTS/case_00215/imaging.nii.gz',
#  './datadownload/KiTS/case_00216/imaging.nii.gz',
#  './datadownload/KiTS/case_00217/imaging.nii.gz',
#  './datadownload/KiTS/case_00218/imaging.nii.gz',
#  './datadownload/KiTS/case_00219/imaging.nii.gz',
#  './datadownload/KiTS/case_00220/imaging.nii.gz',
#  './datadownload/KiTS/case_00221/imaging.nii.gz',
#  './datadownload/KiTS/case_00222/imaging.nii.gz',
#  './datadownload/KiTS/case_00223/imaging.nii.gz',
#  './datadownload/KiTS/case_00224/imaging.nii.gz',
#  './datadownload/KiTS/case_00225/imaging.nii.gz',
#  './datadownload/KiTS/case_00226/imaging.nii.gz',
#  './datadownload/KiTS/case_00227/imaging.nii.gz',
#  './datadownload/KiTS/case_00228/imaging.nii.gz',
#  './datadownload/KiTS/case_00229/imaging.nii.gz',
#  './datadownload/KiTS/case_00230/imaging.nii.gz',
#  './datadownload/KiTS/case_00231/imaging.nii.gz',
#  './datadownload/KiTS/case_00232/imaging.nii.gz',
#  './datadownload/KiTS/case_00233/imaging.nii.gz',
#  './datadownload/KiTS/case_00234/imaging.nii.gz',
#  './datadownload/KiTS/case_00235/imaging.nii.gz',
#  './datadownload/KiTS/case_00236/imaging.nii.gz',
#  './datadownload/KiTS/case_00237/imaging.nii.gz',
#  './datadownload/KiTS/case_00238/imaging.nii.gz',
#  './datadownload/KiTS/case_00239/imaging.nii.gz',
#  './datadownload/KiTS/case_00240/imaging.nii.gz',
#  './datadownload/KiTS/case_00241/imaging.nii.gz',
#  './datadownload/KiTS/case_00242/imaging.nii.gz',
#  './datadownload/KiTS/case_00243/imaging.nii.gz',
#  './datadownload/KiTS/case_00244/imaging.nii.gz',
#  './datadownload/KiTS/case_00245/imaging.nii.gz',
#  './datadownload/KiTS/case_00246/imaging.nii.gz',
#  './datadownload/KiTS/case_00247/imaging.nii.gz',
#  './datadownload/KiTS/case_00248/imaging.nii.gz',
#  './datadownload/KiTS/case_00249/imaging.nii.gz',
#  './datadownload/KiTS/case_00250/imaging.nii.gz',
#  './datadownload/KiTS/case_00251/imaging.nii.gz',
#  './datadownload/KiTS/case_00252/imaging.nii.gz',
#  './datadownload/KiTS/case_00253/imaging.nii.gz',
#  './datadownload/KiTS/case_00254/imaging.nii.gz',
#  './datadownload/KiTS/case_00255/imaging.nii.gz',
#  './datadownload/KiTS/case_00256/imaging.nii.gz',
#  './datadownload/KiTS/case_00257/imaging.nii.gz',
#  './datadownload/KiTS/case_00258/imaging.nii.gz',
#  './datadownload/KiTS/case_00259/imaging.nii.gz',
#  './datadownload/KiTS/case_00260/imaging.nii.gz',
#  './datadownload/KiTS/case_00261/imaging.nii.gz',
#  './datadownload/KiTS/case_00262/imaging.nii.gz',
#  './datadownload/KiTS/case_00263/imaging.nii.gz',
#  './datadownload/KiTS/case_00264/imaging.nii.gz',
#  './datadownload/KiTS/case_00265/imaging.nii.gz',
#  './datadownload/KiTS/case_00266/imaging.nii.gz',
#  './datadownload/KiTS/case_00267/imaging.nii.gz',
#  './datadownload/KiTS/case_00268/imaging.nii.gz',
#  './datadownload/KiTS/case_00269/imaging.nii.gz',
#  './datadownload/KiTS/case_00270/imaging.nii.gz',
#  './datadownload/KiTS/case_00271/imaging.nii.gz',
#  './datadownload/KiTS/case_00272/imaging.nii.gz',
#  './datadownload/KiTS/case_00273/imaging.nii.gz',
#  './datadownload/KiTS/case_00274/imaging.nii.gz',
#  './datadownload/KiTS/case_00275/imaging.nii.gz',
#  './datadownload/KiTS/case_00276/imaging.nii.gz',
#  './datadownload/KiTS/case_00277/imaging.nii.gz',
#  './datadownload/KiTS/case_00278/imaging.nii.gz',
#  './datadownload/KiTS/case_00279/imaging.nii.gz',
#  './datadownload/KiTS/case_00280/imaging.nii.gz',
#  './datadownload/KiTS/case_00281/imaging.nii.gz',
#  './datadownload/KiTS/case_00282/imaging.nii.gz',
#  './datadownload/KiTS/case_00283/imaging.nii.gz',
#  './datadownload/KiTS/case_00284/imaging.nii.gz',
#  './datadownload/KiTS/case_00285/imaging.nii.gz',
#  './datadownload/KiTS/case_00286/imaging.nii.gz',
#  './datadownload/KiTS/case_00287/imaging.nii.gz',
#  './datadownload/KiTS/case_00288/imaging.nii.gz',
#  './datadownload/KiTS/case_00289/imaging.nii.gz',
#  './datadownload/KiTS/case_00290/imaging.nii.gz',
#  './datadownload/KiTS/case_00291/imaging.nii.gz',
#  './datadownload/KiTS/case_00292/imaging.nii.gz',
#  './datadownload/KiTS/case_00293/imaging.nii.gz',
#  './datadownload/KiTS/case_00294/imaging.nii.gz',
#  './datadownload/KiTS/case_00295/imaging.nii.gz',
#  './datadownload/KiTS/case_00296/imaging.nii.gz',
#  './datadownload/KiTS/case_00297/imaging.nii.gz',
#  './datadownload/KiTS/case_00298/imaging.nii.gz',
#  './datadownload/KiTS/case_00299/imaging.nii.gz']

# %%
segs
# Out:
# ['./datadownload/KiTS/case_00000/segmentation.nii.gz',
#  './datadownload/KiTS/case_00001/segmentation.nii.gz',
#  './datadownload/KiTS/case_00002/segmentation.nii.gz',
#  './datadownload/KiTS/case_00003/segmentation.nii.gz',
#  './datadownload/KiTS/case_00004/segmentation.nii.gz',
#  './datadownload/KiTS/case_00005/segmentation.nii.gz',
#  './datadownload/KiTS/case_00006/segmentation.nii.gz',
#  './datadownload/KiTS/case_00007/segmentation.nii.gz',
#  './datadownload/KiTS/case_00008/segmentation.nii.gz',
#  './datadownload/KiTS/case_00009/segmentation.nii.gz',
#  './datadownload/KiTS/case_00010/segmentation.nii.gz',
#  './datadownload/KiTS/case_00011/segmentation.nii.gz',
#  './datadownload/KiTS/case_00012/segmentation.nii.gz',
#  './datadownload/KiTS/case_00013/segmentation.nii.gz',
#  './datadownload/KiTS/case_00014/segmentation.nii.gz',
#  './datadownload/KiTS/case_00015/segmentation.nii.gz',
#  './datadownload/KiTS/case_00016/segmentation.nii.gz',
#  './datadownload/KiTS/case_00017/segmentation.nii.gz',
#  './datadownload/KiTS/case_00018/segmentation.nii.gz',
#  './datadownload/KiTS/case_00019/segmentation.nii.gz',
#  './datadownload/KiTS/case_00020/segmentation.nii.gz',
#  './datadownload/KiTS/case_00021/segmentation.nii.gz',
#  './datadownload/KiTS/case_00022/segmentation.nii.gz',
#  './datadownload/KiTS/case_00023/segmentation.nii.gz',
#  './datadownload/KiTS/case_00024/segmentation.nii.gz',
#  './datadownload/KiTS/case_00025/segmentation.nii.gz',
#  './datadownload/KiTS/case_00026/segmentation.nii.gz',
#  './datadownload/KiTS/case_00027/segmentation.nii.gz',
#  './datadownload/KiTS/case_00028/segmentation.nii.gz',
#  './datadownload/KiTS/case_00029/segmentation.nii.gz',
#  './datadownload/KiTS/case_00030/segmentation.nii.gz',
#  './datadownload/KiTS/case_00031/segmentation.nii.gz',
#  './datadownload/KiTS/case_00032/segmentation.nii.gz',
#  './datadownload/KiTS/case_00033/segmentation.nii.gz',
#  './datadownload/KiTS/case_00034/segmentation.nii.gz',
#  './datadownload/KiTS/case_00035/segmentation.nii.gz',
#  './datadownload/KiTS/case_00036/segmentation.nii.gz',
#  './datadownload/KiTS/case_00037/segmentation.nii.gz',
#  './datadownload/KiTS/case_00038/segmentation.nii.gz',
#  './datadownload/KiTS/case_00039/segmentation.nii.gz',
#  './datadownload/KiTS/case_00040/segmentation.nii.gz',
#  './datadownload/KiTS/case_00041/segmentation.nii.gz',
#  './datadownload/KiTS/case_00042/segmentation.nii.gz',
#  './datadownload/KiTS/case_00043/segmentation.nii.gz',
#  './datadownload/KiTS/case_00044/segmentation.nii.gz',
#  './datadownload/KiTS/case_00045/segmentation.nii.gz',
#  './datadownload/KiTS/case_00046/segmentation.nii.gz',
#  './datadownload/KiTS/case_00047/segmentation.nii.gz',
#  './datadownload/KiTS/case_00048/segmentation.nii.gz',
#  './datadownload/KiTS/case_00049/segmentation.nii.gz',
#  './datadownload/KiTS/case_00050/segmentation.nii.gz',
#  './datadownload/KiTS/case_00051/segmentation.nii.gz',
#  './datadownload/KiTS/case_00052/segmentation.nii.gz',
#  './datadownload/KiTS/case_00053/segmentation.nii.gz',
#  './datadownload/KiTS/case_00054/segmentation.nii.gz',
#  './datadownload/KiTS/case_00055/segmentation.nii.gz',
#  './datadownload/KiTS/case_00056/segmentation.nii.gz',
#  './datadownload/KiTS/case_00057/segmentation.nii.gz',
#  './datadownload/KiTS/case_00058/segmentation.nii.gz',
#  './datadownload/KiTS/case_00059/segmentation.nii.gz',
#  './datadownload/KiTS/case_00060/segmentation.nii.gz',
#  './datadownload/KiTS/case_00061/segmentation.nii.gz',
#  './datadownload/KiTS/case_00062/segmentation.nii.gz',
#  './datadownload/KiTS/case_00063/segmentation.nii.gz',
#  './datadownload/KiTS/case_00064/segmentation.nii.gz',
#  './datadownload/KiTS/case_00065/segmentation.nii.gz',
#  './datadownload/KiTS/case_00066/segmentation.nii.gz',
#  './datadownload/KiTS/case_00067/segmentation.nii.gz',
#  './datadownload/KiTS/case_00068/segmentation.nii.gz',
#  './datadownload/KiTS/case_00069/segmentation.nii.gz',
#  './datadownload/KiTS/case_00070/segmentation.nii.gz',
#  './datadownload/KiTS/case_00071/segmentation.nii.gz',
#  './datadownload/KiTS/case_00072/segmentation.nii.gz',
#  './datadownload/KiTS/case_00073/segmentation.nii.gz',
#  './datadownload/KiTS/case_00074/segmentation.nii.gz',
#  './datadownload/KiTS/case_00075/segmentation.nii.gz',
#  './datadownload/KiTS/case_00076/segmentation.nii.gz',
#  './datadownload/KiTS/case_00077/segmentation.nii.gz',
#  './datadownload/KiTS/case_00078/segmentation.nii.gz',
#  './datadownload/KiTS/case_00079/segmentation.nii.gz',
#  './datadownload/KiTS/case_00080/segmentation.nii.gz',
#  './datadownload/KiTS/case_00081/segmentation.nii.gz',
#  './datadownload/KiTS/case_00082/segmentation.nii.gz',
#  './datadownload/KiTS/case_00083/segmentation.nii.gz',
#  './datadownload/KiTS/case_00084/segmentation.nii.gz',
#  './datadownload/KiTS/case_00085/segmentation.nii.gz',
#  './datadownload/KiTS/case_00086/segmentation.nii.gz',
#  './datadownload/KiTS/case_00087/segmentation.nii.gz',
#  './datadownload/KiTS/case_00088/segmentation.nii.gz',
#  './datadownload/KiTS/case_00089/segmentation.nii.gz',
#  './datadownload/KiTS/case_00090/segmentation.nii.gz',
#  './datadownload/KiTS/case_00091/segmentation.nii.gz',
#  './datadownload/KiTS/case_00092/segmentation.nii.gz',
#  './datadownload/KiTS/case_00093/segmentation.nii.gz',
#  './datadownload/KiTS/case_00094/segmentation.nii.gz',
#  './datadownload/KiTS/case_00095/segmentation.nii.gz',
#  './datadownload/KiTS/case_00096/segmentation.nii.gz',
#  './datadownload/KiTS/case_00097/segmentation.nii.gz',
#  './datadownload/KiTS/case_00098/segmentation.nii.gz',
#  './datadownload/KiTS/case_00099/segmentation.nii.gz',
#  './datadownload/KiTS/case_00100/segmentation.nii.gz',
#  './datadownload/KiTS/case_00101/segmentation.nii.gz',
#  './datadownload/KiTS/case_00102/segmentation.nii.gz',
#  './datadownload/KiTS/case_00103/segmentation.nii.gz',
#  './datadownload/KiTS/case_00104/segmentation.nii.gz',
#  './datadownload/KiTS/case_00105/segmentation.nii.gz',
#  './datadownload/KiTS/case_00106/segmentation.nii.gz',
#  './datadownload/KiTS/case_00107/segmentation.nii.gz',
#  './datadownload/KiTS/case_00108/segmentation.nii.gz',
#  './datadownload/KiTS/case_00109/segmentation.nii.gz',
#  './datadownload/KiTS/case_00110/segmentation.nii.gz',
#  './datadownload/KiTS/case_00111/segmentation.nii.gz',
#  './datadownload/KiTS/case_00112/segmentation.nii.gz',
#  './datadownload/KiTS/case_00113/segmentation.nii.gz',
#  './datadownload/KiTS/case_00114/segmentation.nii.gz',
#  './datadownload/KiTS/case_00115/segmentation.nii.gz',
#  './datadownload/KiTS/case_00116/segmentation.nii.gz',
#  './datadownload/KiTS/case_00117/segmentation.nii.gz',
#  './datadownload/KiTS/case_00118/segmentation.nii.gz',
#  './datadownload/KiTS/case_00119/segmentation.nii.gz',
#  './datadownload/KiTS/case_00120/segmentation.nii.gz',
#  './datadownload/KiTS/case_00121/segmentation.nii.gz',
#  './datadownload/KiTS/case_00122/segmentation.nii.gz',
#  './datadownload/KiTS/case_00123/segmentation.nii.gz',
#  './datadownload/KiTS/case_00124/segmentation.nii.gz',
#  './datadownload/KiTS/case_00125/segmentation.nii.gz',
#  './datadownload/KiTS/case_00126/segmentation.nii.gz',
#  './datadownload/KiTS/case_00127/segmentation.nii.gz',
#  './datadownload/KiTS/case_00128/segmentation.nii.gz',
#  './datadownload/KiTS/case_00129/segmentation.nii.gz',
#  './datadownload/KiTS/case_00130/segmentation.nii.gz',
#  './datadownload/KiTS/case_00131/segmentation.nii.gz',
#  './datadownload/KiTS/case_00132/segmentation.nii.gz',
#  './datadownload/KiTS/case_00133/segmentation.nii.gz',
#  './datadownload/KiTS/case_00134/segmentation.nii.gz',
#  './datadownload/KiTS/case_00135/segmentation.nii.gz',
#  './datadownload/KiTS/case_00136/segmentation.nii.gz',
#  './datadownload/KiTS/case_00137/segmentation.nii.gz',
#  './datadownload/KiTS/case_00138/segmentation.nii.gz',
#  './datadownload/KiTS/case_00139/segmentation.nii.gz',
#  './datadownload/KiTS/case_00140/segmentation.nii.gz',
#  './datadownload/KiTS/case_00141/segmentation.nii.gz',
#  './datadownload/KiTS/case_00142/segmentation.nii.gz',
#  './datadownload/KiTS/case_00143/segmentation.nii.gz',
#  './datadownload/KiTS/case_00144/segmentation.nii.gz',
#  './datadownload/KiTS/case_00145/segmentation.nii.gz',
#  './datadownload/KiTS/case_00146/segmentation.nii.gz',
#  './datadownload/KiTS/case_00147/segmentation.nii.gz',
#  './datadownload/KiTS/case_00148/segmentation.nii.gz',
#  './datadownload/KiTS/case_00149/segmentation.nii.gz',
#  './datadownload/KiTS/case_00150/segmentation.nii.gz',
#  './datadownload/KiTS/case_00151/segmentation.nii.gz',
#  './datadownload/KiTS/case_00152/segmentation.nii.gz',
#  './datadownload/KiTS/case_00153/segmentation.nii.gz',
#  './datadownload/KiTS/case_00154/segmentation.nii.gz',
#  './datadownload/KiTS/case_00155/segmentation.nii.gz',
#  './datadownload/KiTS/case_00156/segmentation.nii.gz',
#  './datadownload/KiTS/case_00157/segmentation.nii.gz',
#  './datadownload/KiTS/case_00158/segmentation.nii.gz',
#  './datadownload/KiTS/case_00159/segmentation.nii.gz',
#  './datadownload/KiTS/case_00160/segmentation.nii.gz',
#  './datadownload/KiTS/case_00161/segmentation.nii.gz',
#  './datadownload/KiTS/case_00162/segmentation.nii.gz',
#  './datadownload/KiTS/case_00163/segmentation.nii.gz',
#  './datadownload/KiTS/case_00164/segmentation.nii.gz',
#  './datadownload/KiTS/case_00165/segmentation.nii.gz',
#  './datadownload/KiTS/case_00166/segmentation.nii.gz',
#  './datadownload/KiTS/case_00167/segmentation.nii.gz',
#  './datadownload/KiTS/case_00168/segmentation.nii.gz',
#  './datadownload/KiTS/case_00169/segmentation.nii.gz',
#  './datadownload/KiTS/case_00170/segmentation.nii.gz',
#  './datadownload/KiTS/case_00171/segmentation.nii.gz',
#  './datadownload/KiTS/case_00172/segmentation.nii.gz',
#  './datadownload/KiTS/case_00173/segmentation.nii.gz',
#  './datadownload/KiTS/case_00174/segmentation.nii.gz',
#  './datadownload/KiTS/case_00175/segmentation.nii.gz',
#  './datadownload/KiTS/case_00176/segmentation.nii.gz',
#  './datadownload/KiTS/case_00177/segmentation.nii.gz',
#  './datadownload/KiTS/case_00178/segmentation.nii.gz',
#  './datadownload/KiTS/case_00179/segmentation.nii.gz',
#  './datadownload/KiTS/case_00180/segmentation.nii.gz',
#  './datadownload/KiTS/case_00181/segmentation.nii.gz',
#  './datadownload/KiTS/case_00182/segmentation.nii.gz',
#  './datadownload/KiTS/case_00183/segmentation.nii.gz',
#  './datadownload/KiTS/case_00184/segmentation.nii.gz',
#  './datadownload/KiTS/case_00185/segmentation.nii.gz',
#  './datadownload/KiTS/case_00186/segmentation.nii.gz',
#  './datadownload/KiTS/case_00187/segmentation.nii.gz',
#  './datadownload/KiTS/case_00188/segmentation.nii.gz',
#  './datadownload/KiTS/case_00189/segmentation.nii.gz',
#  './datadownload/KiTS/case_00190/segmentation.nii.gz',
#  './datadownload/KiTS/case_00191/segmentation.nii.gz',
#  './datadownload/KiTS/case_00192/segmentation.nii.gz',
#  './datadownload/KiTS/case_00193/segmentation.nii.gz',
#  './datadownload/KiTS/case_00194/segmentation.nii.gz',
#  './datadownload/KiTS/case_00195/segmentation.nii.gz',
#  './datadownload/KiTS/case_00196/segmentation.nii.gz',
#  './datadownload/KiTS/case_00197/segmentation.nii.gz',
#  './datadownload/KiTS/case_00198/segmentation.nii.gz',
#  './datadownload/KiTS/case_00199/segmentation.nii.gz',
#  './datadownload/KiTS/case_00200/segmentation.nii.gz',
#  './datadownload/KiTS/case_00201/segmentation.nii.gz',
#  './datadownload/KiTS/case_00202/segmentation.nii.gz',
#  './datadownload/KiTS/case_00203/segmentation.nii.gz',
#  './datadownload/KiTS/case_00204/segmentation.nii.gz',
#  './datadownload/KiTS/case_00205/segmentation.nii.gz',
#  './datadownload/KiTS/case_00206/segmentation.nii.gz',
#  './datadownload/KiTS/case_00207/segmentation.nii.gz',
#  './datadownload/KiTS/case_00208/segmentation.nii.gz',
#  './datadownload/KiTS/case_00209/segmentation.nii.gz']

# %%
pids
# Out:
# ['00000',
#  '00001',
#  '00002',
#  '00003',
#  '00004',
#  '00005',
#  '00006',
#  '00007',
#  '00008',
#  '00009',
#  '00010',
#  '00011',
#  '00012',
#  '00013',
#  '00014',
#  '00015',
#  '00016',
#  '00017',
#  '00018',
#  '00019',
#  '00020',
#  '00021',
#  '00022',
#  '00023',
#  '00024',
#  '00025',
#  '00026',
#  '00027',
#  '00028',
#  '00029',
#  '00030',
#  '00031',
#  '00032',
#  '00033',
#  '00034',
#  '00035',
#  '00036',
#  '00037',
#  '00038',
#  '00039',
#  '00040',
#  '00041',
#  '00042',
#  '00043',
#  '00044',
#  '00045',
#  '00046',
#  '00047',
#  '00048',
#  '00049',
#  '00050',
#  '00051',
#  '00052',
#  '00053',
#  '00054',
#  '00055',
#  '00056',
#  '00057',
#  '00058',
#  '00059',
#  '00060',
#  '00061',
#  '00062',
#  '00063',
#  '00064',
#  '00065',
#  '00066',
#  '00067',
#  '00068',
#  '00069',
#  '00070',
#  '00071',
#  '00072',
#  '00073',
#  '00074',
#  '00075',
#  '00076',
#  '00077',
#  '00078',
#  '00079',
#  '00080',
#  '00081',
#  '00082',
#  '00083',
#  '00084',
#  '00085',
#  '00086',
#  '00087',
#  '00088',
#  '00089',
#  '00090',
#  '00091',
#  '00092',
#  '00093',
#  '00094',
#  '00095',
#  '00096',
#  '00097',
#  '00098',
#  '00099',
#  '00100',
#  '00101',
#  '00102',
#  '00103',
#  '00104',
#  '00105',
#  '00106',
#  '00107',
#  '00108',
#  '00109',
#  '00110',
#  '00111',
#  '00112',
#  '00113',
#  '00114',
#  '00115',
#  '00116',
#  '00117',
#  '00118',
#  '00119',
#  '00120',
#  '00121',
#  '00122',
#  '00123',
#  '00124',
#  '00125',
#  '00126',
#  '00127',
#  '00128',
#  '00129',
#  '00130',
#  '00131',
#  '00132',
#  '00133',
#  '00134',
#  '00135',
#  '00136',
#  '00137',
#  '00138',
#  '00139',
#  '00140',
#  '00141',
#  '00142',
#  '00143',
#  '00144',
#  '00145',
#  '00146',
#  '00147',
#  '00148',
#  '00149',
#  '00150',
#  '00151',
#  '00152',
#  '00153',
#  '00154',
#  '00155',
#  '00156',
#  '00157',
#  '00158',
#  '00159',
#  '00160',
#  '00161',
#  '00162',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00167',
#  '00168',
#  '00169',
#  '00170',
#  '00171',
#  '00172',
#  '00173',
#  '00174',
#  '00175',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00181',
#  '00182',
#  '00183',
#  '00184',
#  '00185',
#  '00186',
#  '00187',
#  '00188',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00199',
#  '00200',
#  '00201',
#  '00202',
#  '00203',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00208',
#  '00209',
#  '00210',
#  '00211',
#  '00212',
#  '00213',
#  '00214',
#  '00215',
#  '00216',
#  '00217',
#  '00218',
#  '00219',
#  '00220',
#  '00221',
#  '00222',
#  '00223',
#  '00224',
#  '00225',
#  '00226',
#  '00227',
#  '00228',
#  '00229',
#  '00230',
#  '00231',
#  '00232',
#  '00233',
#  '00234',
#  '00235',
#  '00236',
#  '00237',
#  '00238',
#  '00239',
#  '00240',
#  '00241',
#  '00242',
#  '00243',
#  '00244',
#  '00245',
#  '00246',
#  '00247',
#  '00248',
#  '00249',
#  '00250',
#  '00251',
#  '00252',
#  '00253',
#  '00254',
#  '00255',
#  '00256',
#  '00257',
#  '00258',
#  '00259',
#  '00260',
#  '00261',
#  '00262',
#  '00263',
#  '00264',
#  '00265',
#  '00266',
#  '00267',
#  '00268',
#  '00269',
#  '00270',
#  '00271',
#  '00272',
#  '00273',
#  '00274',
#  '00275',
#  '00276',
#  '00277',
#  '00278',
#  '00279',
#  '00280',
#  '00281',
#  '00282',
#  '00283',
#  '00284',
#  '00285',
#  '00286',
#  '00287',
#  '00288',
#  '00289',
#  '00290',
#  '00291',
#  '00292',
#  '00293',
#  '00294',
#  '00295',
#  '00296',
#  '00297',
#  '00298',
#  '00299']

# %% [markdown]
# ## Step 1, Data resample

# %%
targetspacing = [1.6, 1.6, 3.2]

# %%
pid = pids[0]
imgfile = imgs[0]
img_obj = sitk.ReadImage( imgfile )

# %%
for (imgfile, lblfile, pid) in zip(imgs, segs, pids):
    savename = 'kidney_' + pid + '.nii.gz'
    img_obj = sitk.ReadImage( imgfile )
    seg_obj = sitk.ReadImage( lblfile )
    
    pa = sitk.PermuteAxesImageFilter()
    pa.SetOrder([2,1,0])
    img_obj = pa.Execute(img_obj)
    seg_obj = pa.Execute(seg_obj)
    
    img_spa_ori = img_obj.GetSpacing()
    res_img_o = resample_by_res(img_obj, targetspacing, interpolator = sitk.sitkLinear,
                                    logging = True)
    res_lb_o = resample_lb_by_res(seg_obj, targetspacing, interpolator = sitk.sitkLinear,
                                  ref_img = res_img_o, logging = True)
    
    res_img_o = sitk.Flip(res_img_o, [False, False, True])
    res_lb_o = sitk.Flip(res_lb_o, [False, False, True])
    
    sitk.WriteImage(res_img_o, datasavepath + 'Image/' + savename, True) 
    sitk.WriteImage(res_lb_o, datasavepath + 'Label/' + savename, True)
# Out:
# Spacing: (0.919921875, 0.919921875, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 611) -> [294.375   294.375    95.46875]
# Label values: [0 1 2]
# Spacing: (0.919921875, 0.919921875, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 611) -> [294.375   294.375    95.46875]
# Spacing: (0.919921875, 0.919921875, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 611) -> [294.375   294.375    95.46875]
# Spacing: (0.919921875, 0.919921875, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 611) -> [294.375   294.375    95.46875]
# Spacing: (0.798828125, 0.798828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 602) -> [255.625  255.625   94.0625]
# Label values: [0 1 2]
# Spacing: (0.798828125, 0.798828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 602) -> [255.625  255.625   94.0625]
# Spacing: (0.798828125, 0.798828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 602) -> [255.625  255.625   94.0625]
# Spacing: (0.798828125, 0.798828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 602) -> [255.625  255.625   94.0625]
# Spacing: (0.939453125, 0.939453125, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 261) -> [300.625  300.625   81.5625]
# Label values: [0 1 2]
# Spacing: (0.939453125, 0.939453125, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 261) -> [300.625  300.625   81.5625]
# Spacing: (0.939453125, 0.939453125, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 261) -> [300.625  300.625   81.5625]
# Spacing: (0.939453125, 0.939453125, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 261) -> [300.625  300.625   81.5625]
# Spacing: (0.85546875, 0.85546875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 270) -> [273.75  273.75   84.375]
# Label values: [0 1 2]
# Spacing: (0.85546875, 0.85546875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 270) -> [273.75  273.75   84.375]
# Spacing: (0.85546875, 0.85546875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 270) -> [273.75  273.75   84.375]
# Spacing: (0.85546875, 0.85546875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 270) -> [273.75  273.75   84.375]
# Spacing: (0.9765625, 0.9765625, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 64) -> [312.5 312.5  80. ]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 64) -> [312.5 312.5  80. ]
# Spacing: (0.9765625, 0.9765625, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 64) -> [312.5 312.5  80. ]
# Spacing: (0.9765625, 0.9765625, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 64) -> [312.5 312.5  80. ]
# Spacing: (0.9765625, 0.9765625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 834) -> [312.5    312.5    130.3125]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 834) -> [312.5    312.5    130.3125]
# Spacing: (0.9765625, 0.9765625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 834) -> [312.5    312.5    130.3125]
# Spacing: (0.9765625, 0.9765625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 834) -> [312.5    312.5    130.3125]
# Spacing: (0.7421875, 0.7421875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 157) -> [237.5    237.5    147.1875]
# Label values: [0 1 2]
# Spacing: (0.7421875, 0.7421875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 157) -> [237.5    237.5    147.1875]
# Spacing: (0.7421875, 0.7421875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 157) -> [237.5    237.5    147.1875]
# Spacing: (0.7421875, 0.7421875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 157) -> [237.5    237.5    147.1875]
# Spacing: (0.939453125, 0.939453125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 61) -> [300.625  300.625   57.1875]
# Label values: [0 1 2]
# Spacing: (0.939453125, 0.939453125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 61) -> [300.625  300.625   57.1875]
# Spacing: (0.939453125, 0.939453125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 61) -> [300.625  300.625   57.1875]
# Spacing: (0.939453125, 0.939453125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 61) -> [300.625  300.625   57.1875]
# Spacing: (0.81640625, 0.81640625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 227) -> [261.25   261.25   212.8125]
# Label values: [0 1 2]
# Spacing: (0.81640625, 0.81640625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 227) -> [261.25   261.25   212.8125]
# Spacing: (0.81640625, 0.81640625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 227) -> [261.25   261.25   212.8125]
# Spacing: (0.81640625, 0.81640625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 227) -> [261.25   261.25   212.8125]
# Spacing: (0.80859375, 0.80859375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 77) -> [258.75   258.75    72.1875]
# Label values: [0 1 2]
# Spacing: (0.80859375, 0.80859375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 77) -> [258.75   258.75    72.1875]
# Spacing: (0.80859375, 0.80859375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 77) -> [258.75   258.75    72.1875]
# Spacing: (0.80859375, 0.80859375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 77) -> [258.75   258.75    72.1875]
# Spacing: (0.7578125, 0.7578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 50) -> [242.5   242.5    46.875]
# Label values: [0 1 2]
# Spacing: (0.7578125, 0.7578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 50) -> [242.5   242.5    46.875]
# Spacing: (0.7578125, 0.7578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 50) -> [242.5   242.5    46.875]
# Spacing: (0.7578125, 0.7578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 50) -> [242.5   242.5    46.875]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [225. 225. 125.]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [225. 225. 125.]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [225. 225. 125.]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [225. 225. 125.]
# Spacing: (0.751953125, 0.751953125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [240.625  240.625  139.0625]
# Label values: [0 1 2]
# Spacing: (0.751953125, 0.751953125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [240.625  240.625  139.0625]
# Spacing: (0.751953125, 0.751953125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [240.625  240.625  139.0625]
# Spacing: (0.751953125, 0.751953125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [240.625  240.625  139.0625]
# Spacing: (0.68359375, 0.68359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 92) -> [218.75 218.75  86.25]
# Label values: [0 1 2]
# Spacing: (0.68359375, 0.68359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 92) -> [218.75 218.75  86.25]
# Spacing: (0.68359375, 0.68359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 92) -> [218.75 218.75  86.25]
# Spacing: (0.68359375, 0.68359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 92) -> [218.75 218.75  86.25]
# Spacing: (0.849609375, 0.849609375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 439) -> [271.875  271.875  137.1875]
# Label values: [0 1 2]
# Spacing: (0.849609375, 0.849609375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 439) -> [271.875  271.875  137.1875]
# Spacing: (0.849609375, 0.849609375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 439) -> [271.875  271.875  137.1875]
# Spacing: (0.849609375, 0.849609375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 439) -> [271.875  271.875  137.1875]
# Spacing: (0.705078125, 0.705078125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [225.625  225.625   70.3125]
# Label values: [0 1 2]
# Spacing: (0.705078125, 0.705078125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [225.625  225.625   70.3125]
# Spacing: (0.705078125, 0.705078125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [225.625  225.625   70.3125]
# Spacing: (0.705078125, 0.705078125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [225.625  225.625   70.3125]
# Spacing: (0.650390625, 0.650390625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [208.125  208.125  139.0625]
# Label values: [0 1 2]
# Spacing: (0.650390625, 0.650390625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [208.125  208.125  139.0625]
# Spacing: (0.650390625, 0.650390625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [208.125  208.125  139.0625]
# Spacing: (0.650390625, 0.650390625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [208.125  208.125  139.0625]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [212.5    212.5    151.5625]
# Label values: [0 1 2]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [212.5    212.5    151.5625]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [212.5    212.5    151.5625]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [212.5    212.5    151.5625]
# Spacing: (0.8613280057907104, 0.8613280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [275.62496185 275.62496185  94.53125   ]
# Label values: [0 1 2]
# Spacing: (0.8613280057907104, 0.8613280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [275.62496185 275.62496185  94.53125   ]
# Spacing: (0.8613280057907104, 0.8613280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [275.62496185 275.62496185  94.53125   ]
# Spacing: (0.8613280057907104, 0.8613280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [275.62496185 275.62496185  94.53125   ]
# Spacing: (0.9375, 0.9375, 3.75) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [300.       300.       151.171875]
# Label values: [0 1 2]
# Spacing: (0.9375, 0.9375, 3.75) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [300.       300.       151.171875]
# Spacing: (0.9375, 0.9375, 3.75) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [300.       300.       151.171875]
# Spacing: (0.9375, 0.9375, 3.75) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [300.       300.       151.171875]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [268.75 268.75 150.  ]
# Label values: [0 1 2]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [268.75 268.75 150.  ]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [268.75 268.75 150.  ]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [268.75 268.75 150.  ]
# Spacing: (0.822265625, 0.822265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [263.125 263.125  59.375]
# Label values: [0 1 2]
# Spacing: (0.822265625, 0.822265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [263.125 263.125  59.375]
# Spacing: (0.822265625, 0.822265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [263.125 263.125  59.375]
# Spacing: (0.822265625, 0.822265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [263.125 263.125  59.375]
# Spacing: (0.833984375, 0.833984375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 541) -> [266.875   266.875    84.53125]
# Label values: [0 1 2]
# Spacing: (0.833984375, 0.833984375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 541) -> [266.875   266.875    84.53125]
# Spacing: (0.833984375, 0.833984375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 541) -> [266.875   266.875    84.53125]
# Spacing: (0.833984375, 0.833984375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 541) -> [266.875   266.875    84.53125]
# Spacing: (0.7820000052452087, 0.7820000052452087, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 107) -> [250.24000168 250.24000168 100.3125    ]
# Label values: [0 1 2]
# Spacing: (0.7820000052452087, 0.7820000052452087, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 107) -> [250.24000168 250.24000168 100.3125    ]
# Spacing: (0.7820000052452087, 0.7820000052452087, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 107) -> [250.24000168 250.24000168 100.3125    ]
# Spacing: (0.7820000052452087, 0.7820000052452087, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 107) -> [250.24000168 250.24000168 100.3125    ]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [212.5    212.5    132.8125]
# Label values: [0 1 2]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [212.5    212.5    132.8125]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [212.5    212.5    132.8125]
# Spacing: (0.6640625, 0.6640625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [212.5    212.5    132.8125]
# Spacing: (0.7363280057907104, 0.7363280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [235.62496185 235.62496185  80.46875   ]
# Label values: [0 1 2]
# Spacing: (0.7363280057907104, 0.7363280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [235.62496185 235.62496185  80.46875   ]
# Spacing: (0.7363280057907104, 0.7363280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [235.62496185 235.62496185  80.46875   ]
# Spacing: (0.7363280057907104, 0.7363280057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [235.62496185 235.62496185  80.46875   ]
# Spacing: (0.875, 0.875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 302) -> [280.     280.     235.9375]
# Label values: [0 1 2]
# Spacing: (0.875, 0.875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 302) -> [280.     280.     235.9375]
# Spacing: (0.875, 0.875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 302) -> [280.     280.     235.9375]
# Spacing: (0.875, 0.875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 302) -> [280.     280.     235.9375]
# Spacing: (0.89453125, 0.89453125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 723) -> [286.25    286.25    112.96875]
# Label values: [0 1 2]
# Spacing: (0.89453125, 0.89453125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 723) -> [286.25    286.25    112.96875]
# Spacing: (0.89453125, 0.89453125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 723) -> [286.25    286.25    112.96875]
# Spacing: (0.89453125, 0.89453125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 723) -> [286.25    286.25    112.96875]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [268.75  268.75  153.125]
# Label values: [0 1 2]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [268.75  268.75  153.125]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [268.75  268.75  153.125]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [268.75  268.75  153.125]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 131) -> [241.25   241.25   204.6875]
# Label values: [0 1 2]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 131) -> [241.25   241.25   204.6875]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 131) -> [241.25   241.25   204.6875]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 131) -> [241.25   241.25   204.6875]
# Spacing: (0.73046875, 0.73046875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [233.75  233.75   59.375]
# Label values: [0 1 2]
# Spacing: (0.73046875, 0.73046875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [233.75  233.75   59.375]
# Spacing: (0.73046875, 0.73046875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [233.75  233.75   59.375]
# Spacing: (0.73046875, 0.73046875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 38) -> [233.75  233.75   59.375]
# Spacing: (0.5180000066757202, 0.5180000066757202, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 117) -> [165.76000214 165.76000214 109.6875    ]
# Label values: [0 1 2]
# Spacing: (0.5180000066757202, 0.5180000066757202, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 117) -> [165.76000214 165.76000214 109.6875    ]
# Spacing: (0.5180000066757202, 0.5180000066757202, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 117) -> [165.76000214 165.76000214 109.6875    ]
# Spacing: (0.5180000066757202, 0.5180000066757202, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 117) -> [165.76000214 165.76000214 109.6875    ]
# Spacing: (0.7792969942092896, 0.7792969942092896, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 189) -> [249.37503815 249.37503815 147.65625   ]
# Label values: [0 1 2]
# Spacing: (0.7792969942092896, 0.7792969942092896, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 189) -> [249.37503815 249.37503815 147.65625   ]
# Spacing: (0.7792969942092896, 0.7792969942092896, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 189) -> [249.37503815 249.37503815 147.65625   ]
# Spacing: (0.7792969942092896, 0.7792969942092896, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 189) -> [249.37503815 249.37503815 147.65625   ]
# Spacing: (0.80859375, 0.80859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 423) -> [258.75   258.75   132.1875]
# Label values: [0 1 2]
# Spacing: (0.80859375, 0.80859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 423) -> [258.75   258.75   132.1875]
# Spacing: (0.80859375, 0.80859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 423) -> [258.75   258.75   132.1875]
# Spacing: (0.80859375, 0.80859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 423) -> [258.75   258.75   132.1875]
# Spacing: (0.8359375, 0.8359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 110) -> [267.5   267.5   171.875]
# Label values: [0 1 2]
# Spacing: (0.8359375, 0.8359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 110) -> [267.5   267.5   171.875]
# Spacing: (0.8359375, 0.8359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 110) -> [267.5   267.5   171.875]
# Spacing: (0.8359375, 0.8359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 110) -> [267.5   267.5   171.875]
# Spacing: (0.96484375, 0.96484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [308.75  308.75  153.125]
# Label values: [0 1 2]
# Spacing: (0.96484375, 0.96484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [308.75  308.75  153.125]
# Spacing: (0.96484375, 0.96484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [308.75  308.75  153.125]
# Spacing: (0.96484375, 0.96484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [308.75  308.75  153.125]
# Spacing: (0.798828125, 0.798828125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 163) -> [255.625  255.625  152.8125]
# Label values: [0 1 2]
# Spacing: (0.798828125, 0.798828125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 163) -> [255.625  255.625  152.8125]
# Spacing: (0.798828125, 0.798828125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 163) -> [255.625  255.625  152.8125]
# Spacing: (0.798828125, 0.798828125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 163) -> [255.625  255.625  152.8125]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [300.     300.     151.5625]
# Label values: [0 1 2]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [300.     300.     151.5625]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [300.     300.     151.5625]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 97) -> [300.     300.     151.5625]
# Spacing: (0.779296875, 0.779296875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 32) -> [249.375 249.375  50.   ]
# Label values: [0 1 2]
# Spacing: (0.779296875, 0.779296875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 32) -> [249.375 249.375  50.   ]
# Spacing: (0.779296875, 0.779296875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 32) -> [249.375 249.375  50.   ]
# Spacing: (0.779296875, 0.779296875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 32) -> [249.375 249.375  50.   ]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [225.    225.    140.625]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [225.    225.    140.625]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [225.    225.    140.625]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [225.    225.    140.625]
# Spacing: (0.7409999966621399, 0.7409999966621399, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 207) -> [237.11999893 237.11999893 129.375     ]
# Label values: [0 1 2]
# Spacing: (0.7409999966621399, 0.7409999966621399, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 207) -> [237.11999893 237.11999893 129.375     ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 207) -> [237.11999893 237.11999893 129.375     ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 207) -> [237.11999893 237.11999893 129.375     ]
# Spacing: (0.677734375, 0.677734375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 52) -> [216.875 216.875  48.75 ]
# Label values: [0 1 2]
# Spacing: (0.677734375, 0.677734375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 52) -> [216.875 216.875  48.75 ]
# Spacing: (0.677734375, 0.677734375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 52) -> [216.875 216.875  48.75 ]
# Spacing: (0.677734375, 0.677734375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 52) -> [216.875 216.875  48.75 ]
# Spacing: (0.859375, 0.859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 301) -> [275.     275.      94.0625]
# Label values: [0 1 2]
# Spacing: (0.859375, 0.859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 301) -> [275.     275.      94.0625]
# Spacing: (0.859375, 0.859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 301) -> [275.     275.      94.0625]
# Spacing: (0.859375, 0.859375, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 301) -> [275.     275.      94.0625]
# Spacing: (0.7379999756813049, 0.7379999756813049, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 172) -> [236.15999222 236.15999222 161.25      ]
# Label values: [0 1 2]
# Spacing: (0.7379999756813049, 0.7379999756813049, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 172) -> [236.15999222 236.15999222 161.25      ]
# Spacing: (0.7379999756813049, 0.7379999756813049, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 172) -> [236.15999222 236.15999222 161.25      ]
# Spacing: (0.7379999756813049, 0.7379999756813049, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 172) -> [236.15999222 236.15999222 161.25      ]
# Spacing: (0.966796875, 0.966796875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [309.375  309.375  157.8125]
# Label values: [0 1 2]
# Spacing: (0.966796875, 0.966796875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [309.375  309.375  157.8125]
# Spacing: (0.966796875, 0.966796875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [309.375  309.375  157.8125]
# Spacing: (0.966796875, 0.966796875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [309.375  309.375  157.8125]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 62) -> [237.11999893 237.11999893  58.125     ]
# Label values: [0 1 2]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 62) -> [237.11999893 237.11999893  58.125     ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 62) -> [237.11999893 237.11999893  58.125     ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 62) -> [237.11999893 237.11999893  58.125     ]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 159) -> [312.5    312.5    149.0625]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 159) -> [312.5    312.5    149.0625]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 159) -> [312.5    312.5    149.0625]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 159) -> [312.5    312.5    149.0625]
# Spacing: (0.85546875, 0.85546875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 142) -> [273.75  273.75  221.875]
# Label values: [0 1 2]
# Spacing: (0.85546875, 0.85546875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 142) -> [273.75  273.75  221.875]
# Spacing: (0.85546875, 0.85546875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 142) -> [273.75  273.75  221.875]
# Spacing: (0.85546875, 0.85546875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 142) -> [273.75  273.75  221.875]
# Spacing: (1.0410000085830688, 1.0410000085830688, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [333.12000275 333.12000275 132.8125    ]
# Label values: [0 1 2]
# Spacing: (1.0410000085830688, 1.0410000085830688, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [333.12000275 333.12000275 132.8125    ]
# Spacing: (1.0410000085830688, 1.0410000085830688, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [333.12000275 333.12000275 132.8125    ]
# Spacing: (1.0410000085830688, 1.0410000085830688, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [333.12000275 333.12000275 132.8125    ]
# Spacing: (0.861328125, 0.861328125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 670) -> [275.625  275.625  104.6875]
# Label values: [0 1 2]
# Spacing: (0.861328125, 0.861328125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 670) -> [275.625  275.625  104.6875]
# Spacing: (0.861328125, 0.861328125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 670) -> [275.625  275.625  104.6875]
# Spacing: (0.861328125, 0.861328125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 670) -> [275.625  275.625  104.6875]
# Spacing: (0.6894530057907104, 0.6894530057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [220.62496185 220.62496185  75.        ]
# Label values: [0 1 2]
# Spacing: (0.6894530057907104, 0.6894530057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [220.62496185 220.62496185  75.        ]
# Spacing: (0.6894530057907104, 0.6894530057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [220.62496185 220.62496185  75.        ]
# Spacing: (0.6894530057907104, 0.6894530057907104, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [220.62496185 220.62496185  75.        ]
# Spacing: (0.9609375, 0.9609375, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 68) -> [307.5   307.5    53.125]
# Label values: [0 1 2]
# Spacing: (0.9609375, 0.9609375, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 68) -> [307.5   307.5    53.125]
# Spacing: (0.9609375, 0.9609375, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 68) -> [307.5   307.5    53.125]
# Spacing: (0.9609375, 0.9609375, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 68) -> [307.5   307.5    53.125]
# Spacing: (0.95703125, 0.95703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 673) -> [306.25    306.25    105.15625]
# Label values: [0 1 2]
# Spacing: (0.95703125, 0.95703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 673) -> [306.25    306.25    105.15625]
# Spacing: (0.95703125, 0.95703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 673) -> [306.25    306.25    105.15625]
# Spacing: (0.95703125, 0.95703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 673) -> [306.25    306.25    105.15625]
# Spacing: (0.7734375, 0.7734375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 553) -> [247.5     247.5      86.40625]
# Label values: [0 1 2]
# Spacing: (0.7734375, 0.7734375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 553) -> [247.5     247.5      86.40625]
# Spacing: (0.7734375, 0.7734375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 553) -> [247.5     247.5      86.40625]
# Spacing: (0.7734375, 0.7734375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 553) -> [247.5     247.5      86.40625]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 104) -> [312.5 312.5 162.5]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 104) -> [312.5 312.5 162.5]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 104) -> [312.5 312.5 162.5]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 104) -> [312.5 312.5 162.5]
# Spacing: (0.87890625, 0.87890625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [281.25   281.25   157.8125]
# Label values: [0 1 2]
# Spacing: (0.87890625, 0.87890625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [281.25   281.25   157.8125]
# Spacing: (0.87890625, 0.87890625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [281.25   281.25   157.8125]
# Spacing: (0.87890625, 0.87890625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 101) -> [281.25   281.25   157.8125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [250.    250.    140.625]
# Label values: [0 1 2]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [250.    250.    140.625]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [250.    250.    140.625]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [250.    250.    140.625]
# Spacing: (0.822265625, 0.822265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [263.125 263.125  75.   ]
# Label values: [0 1 2]
# Spacing: (0.822265625, 0.822265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [263.125 263.125  75.   ]
# Spacing: (0.822265625, 0.822265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [263.125 263.125  75.   ]
# Spacing: (0.822265625, 0.822265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [263.125 263.125  75.   ]
# Spacing: (0.951171875, 0.951171875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [304.375  304.375  160.9375]
# Label values: [0 1 2]
# Spacing: (0.951171875, 0.951171875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [304.375  304.375  160.9375]
# Spacing: (0.951171875, 0.951171875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [304.375  304.375  160.9375]
# Spacing: (0.951171875, 0.951171875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [304.375  304.375  160.9375]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 738) -> [252.5    252.5    115.3125]
# Label values: [0 1 2]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 738) -> [252.5    252.5    115.3125]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 738) -> [252.5    252.5    115.3125]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 738) -> [252.5    252.5    115.3125]
# Spacing: (0.833984375, 0.833984375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [266.875  266.875  135.9375]
# Label values: [0 1 2]
# Spacing: (0.833984375, 0.833984375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [266.875  266.875  135.9375]
# Spacing: (0.833984375, 0.833984375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [266.875  266.875  135.9375]
# Spacing: (0.833984375, 0.833984375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [266.875  266.875  135.9375]
# Spacing: (0.9765620231628418, 0.9765620231628418, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 29) -> [312.49984741 312.49984741  45.3125    ]
# Label values: [0 1 2]
# Spacing: (0.9765620231628418, 0.9765620231628418, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 29) -> [312.49984741 312.49984741  45.3125    ]
# Spacing: (0.9765620231628418, 0.9765620231628418, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 29) -> [312.49984741 312.49984741  45.3125    ]
# Spacing: (0.9765620231628418, 0.9765620231628418, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 29) -> [312.49984741 312.49984741  45.3125    ]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 86) -> [312.5   312.5   134.375]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 86) -> [312.5   312.5   134.375]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 86) -> [312.5   312.5   134.375]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 86) -> [312.5   312.5   134.375]
# Spacing: (0.859375, 0.859375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 527) -> [275.      275.       82.34375]
# Label values: [0 1 2]
# Spacing: (0.859375, 0.859375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 527) -> [275.      275.       82.34375]
# Spacing: (0.859375, 0.859375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 527) -> [275.      275.       82.34375]
# Spacing: (0.859375, 0.859375, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 527) -> [275.      275.       82.34375]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 53) -> [225.     225.      82.8125]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 53) -> [225.     225.      82.8125]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 53) -> [225.     225.      82.8125]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 53) -> [225.     225.      82.8125]
# Spacing: (0.8203120231628418, 0.8203120231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [262.49984741 262.49984741  80.46875   ]
# Label values: [0 1 2]
# Spacing: (0.8203120231628418, 0.8203120231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [262.49984741 262.49984741  80.46875   ]
# Spacing: (0.8203120231628418, 0.8203120231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [262.49984741 262.49984741  80.46875   ]
# Spacing: (0.8203120231628418, 0.8203120231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [262.49984741 262.49984741  80.46875   ]
# Spacing: (0.8632810115814209, 0.8632810115814209, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 445) -> [276.24992371 276.24992371 173.828125  ]
# Label values: [0 1 2]
# Spacing: (0.8632810115814209, 0.8632810115814209, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 445) -> [276.24992371 276.24992371 173.828125  ]
# Spacing: (0.8632810115814209, 0.8632810115814209, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 445) -> [276.24992371 276.24992371 173.828125  ]
# Spacing: (0.8632810115814209, 0.8632810115814209, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 445) -> [276.24992371 276.24992371 173.828125  ]
# Spacing: (0.76171875, 0.76171875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 285) -> [243.75   243.75    89.0625]
# Label values: [0 1 2]
# Spacing: (0.76171875, 0.76171875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 285) -> [243.75   243.75    89.0625]
# Spacing: (0.76171875, 0.76171875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 285) -> [243.75   243.75    89.0625]
# Spacing: (0.76171875, 0.76171875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 285) -> [243.75   243.75    89.0625]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 626) -> [225.     225.      97.8125]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 626) -> [225.     225.      97.8125]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 626) -> [225.     225.      97.8125]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 626) -> [225.     225.      97.8125]
# Spacing: (0.68359375, 0.68359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [218.75  218.75  140.625]
# Label values: [0 1 2]
# Spacing: (0.68359375, 0.68359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [218.75  218.75  140.625]
# Spacing: (0.68359375, 0.68359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [218.75  218.75  140.625]
# Spacing: (0.68359375, 0.68359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [218.75  218.75  140.625]
# Spacing: (0.732421875, 0.732421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 57) -> [234.375  234.375   89.0625]
# Label values: [0 1 2]
# Spacing: (0.732421875, 0.732421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 57) -> [234.375  234.375   89.0625]
# Spacing: (0.732421875, 0.732421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 57) -> [234.375  234.375   89.0625]
# Spacing: (0.732421875, 0.732421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 57) -> [234.375  234.375   89.0625]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 612) -> [225.    225.     95.625]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 612) -> [225.    225.     95.625]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 612) -> [225.    225.     95.625]
# Spacing: (0.703125, 0.703125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 612) -> [225.    225.     95.625]
# Spacing: (0.6640625, 0.6640625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 164) -> [212.5   212.5   128.125]
# Label values: [0 1 2]
# Spacing: (0.6640625, 0.6640625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 164) -> [212.5   212.5   128.125]
# Spacing: (0.6640625, 0.6640625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 164) -> [212.5   212.5   128.125]
# Spacing: (0.6640625, 0.6640625, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 164) -> [212.5   212.5   128.125]
# Spacing: (0.859375, 0.859375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [275.     275.     226.5625]
# Label values: [0 1 2]
# Spacing: (0.859375, 0.859375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [275.     275.     226.5625]
# Spacing: (0.859375, 0.859375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [275.     275.     226.5625]
# Spacing: (0.859375, 0.859375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 145) -> [275.     275.     226.5625]
# Spacing: (0.6484375, 0.6484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [207.5 207.5 125. ]
# Label values: [0 1 2]
# Spacing: (0.6484375, 0.6484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [207.5 207.5 125. ]
# Spacing: (0.6484375, 0.6484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [207.5 207.5 125. ]
# Spacing: (0.6484375, 0.6484375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 80) -> [207.5 207.5 125. ]
# Spacing: (0.70703125, 0.70703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [226.25  226.25  140.625]
# Label values: [0 1 2]
# Spacing: (0.70703125, 0.70703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [226.25  226.25  140.625]
# Spacing: (0.70703125, 0.70703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [226.25  226.25  140.625]
# Spacing: (0.70703125, 0.70703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 90) -> [226.25  226.25  140.625]
# Spacing: (0.677734375, 0.677734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 66) -> [216.875 216.875 103.125]
# Label values: [0 1 2]
# Spacing: (0.677734375, 0.677734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 66) -> [216.875 216.875 103.125]
# Spacing: (0.677734375, 0.677734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 66) -> [216.875 216.875 103.125]
# Spacing: (0.677734375, 0.677734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 66) -> [216.875 216.875 103.125]
# Spacing: (0.705078125, 0.705078125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [225.625 225.625 137.5  ]
# Label values: [0 1 2]
# Spacing: (0.705078125, 0.705078125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [225.625 225.625 137.5  ]
# Spacing: (0.705078125, 0.705078125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [225.625 225.625 137.5  ]
# Spacing: (0.705078125, 0.705078125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [225.625 225.625 137.5  ]
# Spacing: (0.962890625, 0.962890625, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 326) -> [308.125 308.125 101.875]
# Label values: [0 1 2]
# Spacing: (0.962890625, 0.962890625, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 326) -> [308.125 308.125 101.875]
# Spacing: (0.962890625, 0.962890625, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 326) -> [308.125 308.125 101.875]
# Spacing: (0.962890625, 0.962890625, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 326) -> [308.125 308.125 101.875]
# Spacing: (0.64453125, 0.64453125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 124) -> [206.25 206.25 193.75]
# Label values: [0 1 2]
# Spacing: (0.64453125, 0.64453125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 124) -> [206.25 206.25 193.75]
# Spacing: (0.64453125, 0.64453125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 124) -> [206.25 206.25 193.75]
# Spacing: (0.64453125, 0.64453125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 124) -> [206.25 206.25 193.75]
# Spacing: (0.72265625, 0.72265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [231.25 231.25 137.5 ]
# Label values: [0 1 2]
# Spacing: (0.72265625, 0.72265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [231.25 231.25 137.5 ]
# Spacing: (0.72265625, 0.72265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [231.25 231.25 137.5 ]
# Spacing: (0.72265625, 0.72265625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [231.25 231.25 137.5 ]
# Spacing: (0.984000027179718, 0.984000027179718, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 151) -> [314.8800087 314.8800087 141.5625   ]
# Label values: [0 1 2]
# Spacing: (0.984000027179718, 0.984000027179718, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 151) -> [314.8800087 314.8800087 141.5625   ]
# Spacing: (0.984000027179718, 0.984000027179718, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 151) -> [314.8800087 314.8800087 141.5625   ]
# Spacing: (0.984000027179718, 0.984000027179718, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 151) -> [314.8800087 314.8800087 141.5625   ]
# Spacing: (0.779296875, 0.779296875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [249.375  249.375  120.9375]
# Label values: [0 1 2]
# Spacing: (0.779296875, 0.779296875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [249.375  249.375  120.9375]
# Spacing: (0.779296875, 0.779296875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [249.375  249.375  120.9375]
# Spacing: (0.779296875, 0.779296875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 129) -> [249.375  249.375  120.9375]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 94) -> [312.5   312.5    88.125]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 94) -> [312.5   312.5    88.125]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 94) -> [312.5   312.5    88.125]
# Spacing: (0.9765625, 0.9765625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 94) -> [312.5   312.5    88.125]
# Spacing: (0.9765625, 0.9765625, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 274) -> [312.5  312.5  171.25]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 274) -> [312.5  312.5  171.25]
# Spacing: (0.9765625, 0.9765625, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 274) -> [312.5  312.5  171.25]
# Spacing: (0.9765625, 0.9765625, 2.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 274) -> [312.5  312.5  171.25]
# Spacing: (0.8119999766349792, 0.8119999766349792, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 87) -> [259.83999252 259.83999252 135.9375    ]
# Label values: [0 1 2]
# Spacing: (0.8119999766349792, 0.8119999766349792, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 87) -> [259.83999252 259.83999252 135.9375    ]
# Spacing: (0.8119999766349792, 0.8119999766349792, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 87) -> [259.83999252 259.83999252 135.9375    ]
# Spacing: (0.8119999766349792, 0.8119999766349792, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 87) -> [259.83999252 259.83999252 135.9375    ]
# Spacing: (0.7890620231628418, 0.7890620231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 199) -> [252.49984741 252.49984741 155.46875   ]
# Label values: [0 1 2]
# Spacing: (0.7890620231628418, 0.7890620231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 199) -> [252.49984741 252.49984741 155.46875   ]
# Spacing: (0.7890620231628418, 0.7890620231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 199) -> [252.49984741 252.49984741 155.46875   ]
# Spacing: (0.7890620231628418, 0.7890620231628418, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 199) -> [252.49984741 252.49984741 155.46875   ]
# Spacing: (0.69140625, 0.69140625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 49) -> [221.25   221.25    76.5625]
# Label values: [0 1 2]
# Spacing: (0.69140625, 0.69140625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 49) -> [221.25   221.25    76.5625]
# Spacing: (0.69140625, 0.69140625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 49) -> [221.25   221.25    76.5625]
# Spacing: (0.69140625, 0.69140625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 49) -> [221.25   221.25    76.5625]
# Spacing: (0.4375, 0.4375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [140.     140.      92.8125]
# Label values: [0 1 2]
# Spacing: (0.4375, 0.4375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [140.     140.      92.8125]
# Spacing: (0.4375, 0.4375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [140.     140.      92.8125]
# Spacing: (0.4375, 0.4375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [140.     140.      92.8125]
# Spacing: (0.908203125, 0.908203125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 55) -> [290.625  290.625   85.9375]
# Label values: [0 1 2]
# Spacing: (0.908203125, 0.908203125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 55) -> [290.625  290.625   85.9375]
# Spacing: (0.908203125, 0.908203125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 55) -> [290.625  290.625   85.9375]
# Spacing: (0.908203125, 0.908203125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 55) -> [290.625  290.625   85.9375]
# Spacing: (0.767578125, 0.767578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 76) -> [245.625 245.625  71.25 ]
# Label values: [0 1 2]
# Spacing: (0.767578125, 0.767578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 76) -> [245.625 245.625  71.25 ]
# Spacing: (0.767578125, 0.767578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 76) -> [245.625 245.625  71.25 ]
# Spacing: (0.767578125, 0.767578125, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 76) -> [245.625 245.625  71.25 ]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 735) -> [252.5     252.5     114.84375]
# Label values: [0 1 2]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 735) -> [252.5     252.5     114.84375]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 735) -> [252.5     252.5     114.84375]
# Spacing: (0.7890625, 0.7890625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 735) -> [252.5     252.5     114.84375]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [225.    225.    153.125]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [225.    225.    153.125]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [225.    225.    153.125]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [225.    225.    153.125]
# Spacing: (0.91015625, 0.91015625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 787) -> [291.25    291.25    122.96875]
# Label values: [0 1 2]
# Spacing: (0.91015625, 0.91015625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 787) -> [291.25    291.25    122.96875]
# Spacing: (0.91015625, 0.91015625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 787) -> [291.25    291.25    122.96875]
# Spacing: (0.91015625, 0.91015625, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 787) -> [291.25    291.25    122.96875]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 43) -> [225.     225.      67.1875]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 43) -> [225.     225.      67.1875]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 43) -> [225.     225.      67.1875]
# Spacing: (0.703125, 0.703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 43) -> [225.     225.      67.1875]
# Spacing: (0.93359375, 0.93359375, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 314) -> [298.75   298.75   147.1875]
# Label values: [0 1 2]
# Spacing: (0.93359375, 0.93359375, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 314) -> [298.75   298.75   147.1875]
# Spacing: (0.93359375, 0.93359375, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 314) -> [298.75   298.75   147.1875]
# Spacing: (0.93359375, 0.93359375, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 314) -> [298.75   298.75   147.1875]
# Spacing: (0.73828125, 0.73828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 683) -> [236.25    236.25    106.71875]
# Label values: [0 1 2]
# Spacing: (0.73828125, 0.73828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 683) -> [236.25    236.25    106.71875]
# Spacing: (0.73828125, 0.73828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 683) -> [236.25    236.25    106.71875]
# Spacing: (0.73828125, 0.73828125, 0.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 683) -> [236.25    236.25    106.71875]
# Spacing: (0.7409999966621399, 0.7409999966621399, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [237.11999893 237.11999893 132.8125    ]
# Label values: [0 1 2]
# Spacing: (0.7409999966621399, 0.7409999966621399, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [237.11999893 237.11999893 132.8125    ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [237.11999893 237.11999893 132.8125    ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 85) -> [237.11999893 237.11999893 132.8125    ]
# Spacing: (0.69921875, 0.69921875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 234) -> [223.75  223.75   73.125]
# Label values: [0 1 2]
# Spacing: (0.69921875, 0.69921875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 234) -> [223.75  223.75   73.125]
# Spacing: (0.69921875, 0.69921875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 234) -> [223.75  223.75   73.125]
# Spacing: (0.69921875, 0.69921875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 234) -> [223.75  223.75   73.125]
# Spacing: (0.7070310115814209, 0.7070310115814209, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 105) -> [226.24992371 226.24992371 164.0625    ]
# Label values: [0 1 2]
# Spacing: (0.7070310115814209, 0.7070310115814209, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 105) -> [226.24992371 226.24992371 164.0625    ]
# Spacing: (0.7070310115814209, 0.7070310115814209, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 105) -> [226.24992371 226.24992371 164.0625    ]
# Spacing: (0.7070310115814209, 0.7070310115814209, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 105) -> [226.24992371 226.24992371 164.0625    ]
# Spacing: (0.82421875, 0.82421875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 470) -> [263.75  263.75  146.875]
# Label values: [0 1 2]
# Spacing: (0.82421875, 0.82421875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 470) -> [263.75  263.75  146.875]
# ...
# Size (512, 512, 107) -> [233.75   233.75   167.1875]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [312.5   312.5   159.375]
# Label values: [0 1 2]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [312.5   312.5   159.375]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [312.5   312.5   159.375]
# Spacing: (0.9765625, 0.9765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [312.5   312.5   159.375]
# Spacing: (0.673828125, 0.673828125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [215.625 215.625 137.5  ]
# Label values: [0 1 2]
# Spacing: (0.673828125, 0.673828125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [215.625 215.625 137.5  ]
# Spacing: (0.673828125, 0.673828125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [215.625 215.625 137.5  ]
# Spacing: (0.673828125, 0.673828125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [215.625 215.625 137.5  ]
# Spacing: (0.865234375, 0.865234375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [276.875 276.875 137.5  ]
# Label values: [0 1 2]
# Spacing: (0.865234375, 0.865234375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [276.875 276.875 137.5  ]
# Spacing: (0.865234375, 0.865234375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [276.875 276.875 137.5  ]
# Spacing: (0.865234375, 0.865234375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 88) -> [276.875 276.875 137.5  ]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [237.5    237.5    154.6875]
# Label values: [0 1 2]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [237.5    237.5    154.6875]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [237.5    237.5    154.6875]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [237.5    237.5    154.6875]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 137) -> [237.11999893 237.11999893 128.4375    ]
# Label values: [0 1 2]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 137) -> [237.11999893 237.11999893 128.4375    ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 137) -> [237.11999893 237.11999893 128.4375    ]
# Spacing: (0.7409999966621399, 0.7409999966621399, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 137) -> [237.11999893 237.11999893 128.4375    ]
# Spacing: (0.693359375, 0.693359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [221.875  221.875  154.6875]
# Label values: [0 1 2]
# Spacing: (0.693359375, 0.693359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [221.875  221.875  154.6875]
# Spacing: (0.693359375, 0.693359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [221.875  221.875  154.6875]
# Spacing: (0.693359375, 0.693359375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 99) -> [221.875  221.875  154.6875]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [300.     300.     145.3125]
# Label values: [0 1 2]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [300.     300.     145.3125]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [300.     300.     145.3125]
# Spacing: (0.9375, 0.9375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [300.     300.     145.3125]
# Spacing: (0.70703125, 0.70703125, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 195) -> [226.25    226.25     91.40625]
# Label values: [0 1 2]
# Spacing: (0.70703125, 0.70703125, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 195) -> [226.25    226.25     91.40625]
# Spacing: (0.70703125, 0.70703125, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 195) -> [226.25    226.25     91.40625]
# Spacing: (0.70703125, 0.70703125, 1.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 195) -> [226.25    226.25     91.40625]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [268.75  268.75  228.125]
# Label values: [0 1 2]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [268.75  268.75  228.125]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [268.75  268.75  228.125]
# Spacing: (0.83984375, 0.83984375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [268.75  268.75  228.125]
# Spacing: (0.9121090173721313, 0.9121090173721313, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 235) -> [291.87488556 291.87488556 183.59375   ]
# Label values: [0 1 2]
# Spacing: (0.9121090173721313, 0.9121090173721313, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 235) -> [291.87488556 291.87488556 183.59375   ]
# Spacing: (0.9121090173721313, 0.9121090173721313, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 235) -> [291.87488556 291.87488556 183.59375   ]
# Spacing: (0.9121090173721313, 0.9121090173721313, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 235) -> [291.87488556 291.87488556 183.59375   ]
# Spacing: (0.734375, 0.734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 143) -> [235.     235.     223.4375]
# Label values: [0 1 2]
# Spacing: (0.734375, 0.734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 143) -> [235.     235.     223.4375]
# Spacing: (0.734375, 0.734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 143) -> [235.     235.     223.4375]
# Spacing: (0.734375, 0.734375, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 143) -> [235.     235.     223.4375]
# Spacing: (0.625, 0.625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 82) -> [200.    200.    128.125]
# Label values: [0 1 2]
# Spacing: (0.625, 0.625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 82) -> [200.    200.    128.125]
# Spacing: (0.625, 0.625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 82) -> [200.    200.    128.125]
# Spacing: (0.625, 0.625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 82) -> [200.    200.    128.125]
# Spacing: (0.6796875, 0.6796875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 365) -> [217.5    217.5    114.0625]
# Label values: [0 1 2]
# Spacing: (0.6796875, 0.6796875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 365) -> [217.5    217.5    114.0625]
# Spacing: (0.6796875, 0.6796875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 365) -> [217.5    217.5    114.0625]
# Spacing: (0.6796875, 0.6796875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 365) -> [217.5    217.5    114.0625]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [237.5   237.5   228.125]
# Label values: [0 1 2]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [237.5   237.5   228.125]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [237.5   237.5   228.125]
# Spacing: (0.7421875, 0.7421875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 146) -> [237.5   237.5   228.125]
# Spacing: (0.72265625, 0.72265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 161) -> [231.25   231.25   150.9375]
# Label values: [0 1 2]
# Spacing: (0.72265625, 0.72265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 161) -> [231.25   231.25   150.9375]
# Spacing: (0.72265625, 0.72265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 161) -> [231.25   231.25   150.9375]
# Spacing: (0.72265625, 0.72265625, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 161) -> [231.25   231.25   150.9375]
# Spacing: (0.7421879768371582, 0.7421879768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 349) -> [237.50015259 237.50015259 136.328125  ]
# Label values: [0 1 2]
# Spacing: (0.7421879768371582, 0.7421879768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 349) -> [237.50015259 237.50015259 136.328125  ]
# Spacing: (0.7421879768371582, 0.7421879768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 349) -> [237.50015259 237.50015259 136.328125  ]
# Spacing: (0.7421879768371582, 0.7421879768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 349) -> [237.50015259 237.50015259 136.328125  ]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 133) -> [250.     250.     207.8125]
# Label values: [0 1 2]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 133) -> [250.     250.     207.8125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 133) -> [250.     250.     207.8125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 133) -> [250.     250.     207.8125]
# Spacing: (0.703125, 0.703125, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 233) -> [225.       225.        91.015625]
# Label values: [0 1 2]
# Spacing: (0.703125, 0.703125, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 233) -> [225.       225.        91.015625]
# Spacing: (0.703125, 0.703125, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 233) -> [225.       225.        91.015625]
# Spacing: (0.703125, 0.703125, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 233) -> [225.       225.        91.015625]
# Spacing: (0.75, 0.75, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 135) -> [240.     240.     210.9375]
# Label values: [0 1 2]
# Spacing: (0.75, 0.75, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 135) -> [240.     240.     210.9375]
# Spacing: (0.75, 0.75, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 135) -> [240.     240.     210.9375]
# Spacing: (0.75, 0.75, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 135) -> [240.     240.     210.9375]
# Spacing: (0.763671875, 0.763671875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [244.375 244.375 153.125]
# Label values: [0 1 2]
# Spacing: (0.763671875, 0.763671875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [244.375 244.375 153.125]
# Spacing: (0.763671875, 0.763671875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [244.375 244.375 153.125]
# Spacing: (0.763671875, 0.763671875, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 98) -> [244.375 244.375 153.125]
# Spacing: (0.818359375, 0.818359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [261.875 261.875 166.875]
# Label values: [0 1 2]
# Spacing: (0.818359375, 0.818359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [261.875 261.875 166.875]
# Spacing: (0.818359375, 0.818359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [261.875 261.875 166.875]
# Spacing: (0.818359375, 0.818359375, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 178) -> [261.875 261.875 166.875]
# Spacing: (0.873046875, 0.873046875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 162) -> [279.375 279.375 151.875]
# Label values: [0 1 2]
# Spacing: (0.873046875, 0.873046875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 162) -> [279.375 279.375 151.875]
# Spacing: (0.873046875, 0.873046875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 162) -> [279.375 279.375 151.875]
# Spacing: (0.873046875, 0.873046875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 162) -> [279.375 279.375 151.875]
# Spacing: (0.732421875, 0.732421875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 269) -> [234.375   234.375   210.15625]
# Label values: [0 1 2]
# Spacing: (0.732421875, 0.732421875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 269) -> [234.375   234.375   210.15625]
# Spacing: (0.732421875, 0.732421875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 269) -> [234.375   234.375   210.15625]
# Spacing: (0.732421875, 0.732421875, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 269) -> [234.375   234.375   210.15625]
# Spacing: (0.7421879768371582, 0.7421879768371582, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [237.50015259 237.50015259  94.53125   ]
# Label values: [0 1 2]
# Spacing: (0.7421879768371582, 0.7421879768371582, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [237.50015259 237.50015259  94.53125   ]
# Spacing: (0.7421879768371582, 0.7421879768371582, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [237.50015259 237.50015259  94.53125   ]
# Spacing: (0.7421879768371582, 0.7421879768371582, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 121) -> [237.50015259 237.50015259  94.53125   ]
# Spacing: (0.7421875, 0.7421875, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [237.5  237.5  128.75]
# Label values: [0 1 2]
# Spacing: (0.7421875, 0.7421875, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [237.5  237.5  128.75]
# Spacing: (0.7421875, 0.7421875, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [237.5  237.5  128.75]
# Spacing: (0.7421875, 0.7421875, 4.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 103) -> [237.5  237.5  128.75]
# Spacing: (0.78125, 0.78125, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [250. 250.  75.]
# Label values: [0 1 2]
# Spacing: (0.78125, 0.78125, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [250. 250.  75.]
# Spacing: (0.78125, 0.78125, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [250. 250.  75.]
# Spacing: (0.78125, 0.78125, 2.5) -> [1.6, 1.6, 3.2]
# Size (512, 512, 96) -> [250. 250.  75.]
# Spacing: (0.8984379768371582, 0.8984379768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 383) -> [287.50015259 287.50015259 149.609375  ]
# Label values: [0 1 2]
# Spacing: (0.8984379768371582, 0.8984379768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 383) -> [287.50015259 287.50015259 149.609375  ]
# Spacing: (0.8984379768371582, 0.8984379768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 383) -> [287.50015259 287.50015259 149.609375  ]
# Spacing: (0.8984379768371582, 0.8984379768371582, 1.25) -> [1.6, 1.6, 3.2]
# Size (512, 512, 383) -> [287.50015259 287.50015259 149.609375  ]
# Spacing: (0.63671875, 0.63671875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 620) -> [203.75 203.75 193.75]
# Label values: [0 1 2]
# Spacing: (0.63671875, 0.63671875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 620) -> [203.75 203.75 193.75]
# Spacing: (0.63671875, 0.63671875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 620) -> [203.75 203.75 193.75]
# Spacing: (0.63671875, 0.63671875, 1.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 620) -> [203.75 203.75 193.75]
# Spacing: (0.875, 0.875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [280.     280.      70.3125]
# Label values: [0 1 2]
# Spacing: (0.875, 0.875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [280.     280.      70.3125]
# Spacing: (0.875, 0.875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [280.     280.      70.3125]
# Spacing: (0.875, 0.875, 3.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 75) -> [280.     280.      70.3125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [250.     250.     145.3125]
# Label values: [0 1 2]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [250.     250.     145.3125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [250.     250.     145.3125]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 93) -> [250.     250.     145.3125]
# Spacing: (0.970703125, 0.970703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 60) -> [310.625 310.625  93.75 ]
# Label values: [0 1 2]
# Spacing: (0.970703125, 0.970703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 60) -> [310.625 310.625  93.75 ]
# Spacing: (0.970703125, 0.970703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 60) -> [310.625 310.625  93.75 ]
# Spacing: (0.970703125, 0.970703125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 60) -> [310.625 310.625  93.75 ]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 140) -> [241.25 241.25 218.75]
# Label values: [0 1 2]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 140) -> [241.25 241.25 218.75]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 140) -> [241.25 241.25 218.75]
# Spacing: (0.75390625, 0.75390625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 140) -> [241.25 241.25 218.75]
# Spacing: (0.884765625, 0.884765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [283.125  283.125  139.0625]
# Label values: [0 1 2]
# Spacing: (0.884765625, 0.884765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [283.125  283.125  139.0625]
# Spacing: (0.884765625, 0.884765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [283.125  283.125  139.0625]
# Spacing: (0.884765625, 0.884765625, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 89) -> [283.125  283.125  139.0625]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [250.    250.    159.375]
# Label values: [0 1 2]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [250.    250.    159.375]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [250.    250.    159.375]
# Spacing: (0.78125, 0.78125, 5.0) -> [1.6, 1.6, 3.2]
# Size (512, 512, 102) -> [250.    250.    159.375]

# %% [markdown]
# ## Step 2, Intensity Normalization

# %%
IMG_FOLDER_SAVE = datasavepath + 'Image/'
imgs = glob.glob(IMG_FOLDER_SAVE + "/kidney_*.nii.gz")
imgs = [ fid for fid in sorted(imgs) ]

# %%
pixel_mean = 101
pixel_std = 76.9
intensity_05percent = -79
intensity_995percent = 304

# %%
for (imgfile, pid) in zip(imgs, pids):
    savename = 'kidney_' + pid + '.nii.gz'
    img_obj = sitk.ReadImage( imgfile )
    
    array = sitk.GetArrayFromImage(img_obj)

    array[array < intensity_05percent] = intensity_05percent
    array[array > intensity_995percent] = intensity_995percent
    array = (array - pixel_mean) / pixel_std

    normalized_img = sitk.GetImageFromArray(array)
    normalized_img.CopyInformation(img_obj)
    
    sitk.WriteImage(normalized_img, datasavepath + 'processed/' + savename, True) 
    print('Id ' + pid + ' normalized')
# Out:
# Id 00000 normalized
# Id 00001 normalized
# Id 00002 normalized
# Id 00003 normalized
# Id 00004 normalized
# Id 00005 normalized
# Id 00006 normalized
# Id 00007 normalized
# Id 00008 normalized
# Id 00009 normalized
# Id 00010 normalized
# Id 00011 normalized
# Id 00012 normalized
# Id 00013 normalized
# Id 00014 normalized
# Id 00015 normalized
# Id 00016 normalized
# Id 00017 normalized
# Id 00018 normalized
# Id 00019 normalized
# Id 00020 normalized
# Id 00021 normalized
# Id 00022 normalized
# Id 00023 normalized
# Id 00024 normalized
# Id 00025 normalized
# Id 00026 normalized
# Id 00027 normalized
# Id 00028 normalized
# Id 00029 normalized
# Id 00030 normalized
# Id 00031 normalized
# Id 00032 normalized
# Id 00033 normalized
# Id 00034 normalized
# Id 00035 normalized
# Id 00036 normalized
# Id 00037 normalized
# Id 00038 normalized
# Id 00039 normalized
# Id 00040 normalized
# Id 00041 normalized
# Id 00042 normalized
# Id 00043 normalized
# Id 00044 normalized
# Id 00045 normalized
# Id 00046 normalized
# Id 00047 normalized
# Id 00048 normalized
# Id 00049 normalized
# Id 00050 normalized
# Id 00051 normalized
# Id 00052 normalized
# Id 00053 normalized
# Id 00054 normalized
# Id 00055 normalized
# Id 00056 normalized
# Id 00057 normalized
# Id 00058 normalized
# Id 00059 normalized
# Id 00060 normalized
# Id 00061 normalized
# Id 00062 normalized
# Id 00063 normalized
# Id 00064 normalized
# Id 00065 normalized
# Id 00066 normalized
# Id 00067 normalized
# Id 00068 normalized
# Id 00069 normalized
# Id 00070 normalized
# Id 00071 normalized
# Id 00072 normalized
# Id 00073 normalized
# Id 00074 normalized
# Id 00075 normalized
# Id 00076 normalized
# Id 00077 normalized
# Id 00078 normalized
# Id 00079 normalized
# Id 00080 normalized
# Id 00081 normalized
# Id 00082 normalized
# Id 00083 normalized
# Id 00084 normalized
# Id 00085 normalized
# Id 00086 normalized
# Id 00087 normalized
# Id 00088 normalized
# Id 00089 normalized
# Id 00090 normalized
# Id 00091 normalized
# Id 00092 normalized
# Id 00093 normalized
# Id 00094 normalized
# Id 00095 normalized
# Id 00096 normalized
# Id 00097 normalized
# Id 00098 normalized
# Id 00099 normalized
# Id 00100 normalized
# Id 00101 normalized
# Id 00102 normalized
# Id 00103 normalized
# Id 00104 normalized
# Id 00105 normalized
# Id 00106 normalized
# Id 00107 normalized
# Id 00108 normalized
# Id 00109 normalized
# Id 00110 normalized
# Id 00111 normalized
# Id 00112 normalized
# Id 00113 normalized
# Id 00114 normalized
# Id 00115 normalized
# Id 00116 normalized
# Id 00117 normalized
# Id 00118 normalized
# Id 00119 normalized
# Id 00120 normalized
# Id 00121 normalized
# Id 00122 normalized
# Id 00123 normalized
# Id 00124 normalized
# Id 00125 normalized
# Id 00126 normalized
# Id 00127 normalized
# Id 00128 normalized
# Id 00129 normalized
# Id 00130 normalized
# Id 00131 normalized
# Id 00132 normalized
# Id 00133 normalized
# Id 00134 normalized
# Id 00135 normalized
# Id 00136 normalized
# Id 00137 normalized
# Id 00138 normalized
# Id 00139 normalized
# Id 00140 normalized
# Id 00141 normalized
# Id 00142 normalized
# Id 00143 normalized
# Id 00144 normalized
# Id 00145 normalized
# Id 00146 normalized
# Id 00147 normalized
# Id 00148 normalized
# Id 00149 normalized
# Id 00150 normalized
# Id 00151 normalized
# Id 00152 normalized
# Id 00153 normalized
# Id 00154 normalized
# Id 00155 normalized
# Id 00156 normalized
# Id 00157 normalized
# Id 00158 normalized
# Id 00159 normalized
# Id 00160 normalized
# Id 00161 normalized
# Id 00162 normalized
# Id 00163 normalized
# Id 00164 normalized
# Id 00165 normalized
# Id 00166 normalized
# Id 00167 normalized
# Id 00168 normalized
# Id 00169 normalized
# Id 00170 normalized
# Id 00171 normalized
# Id 00172 normalized
# Id 00173 normalized
# Id 00174 normalized
# Id 00175 normalized
# Id 00176 normalized
# Id 00177 normalized
# Id 00178 normalized
# Id 00179 normalized
# Id 00180 normalized
# Id 00181 normalized
# Id 00182 normalized
# Id 00183 normalized
# Id 00184 normalized
# Id 00185 normalized
# Id 00186 normalized
# Id 00187 normalized
# Id 00188 normalized
# Id 00189 normalized
# Id 00190 normalized
# Id 00191 normalized
# Id 00192 normalized
# Id 00193 normalized
# Id 00194 normalized
# Id 00195 normalized
# Id 00196 normalized
# Id 00197 normalized
# Id 00198 normalized
# Id 00199 normalized
# Id 00200 normalized
# Id 00201 normalized
# Id 00202 normalized
# Id 00203 normalized
# Id 00204 normalized
# Id 00205 normalized
# Id 00206 normalized
# Id 00207 normalized
# Id 00208 normalized
# Id 00209 normalized

# %% [markdown]
# ## Step 3, Generate Body Masks

# %%
IMG_FOLDER_SAVE = datasavepath + 'Image/'
imgs = glob.glob(IMG_FOLDER_SAVE + "/kidney_*.nii.gz")
imgs = [ fid for fid in sorted(imgs) ]

# %%
threshold = -200

# %%
for (imgfile, pid) in zip(imgs, pids):
    savename = 'kidney_' + pid + '.nii.gz'
    img_obj = sitk.ReadImage( imgfile )
    array = sitk.GetArrayFromImage(img_obj)
    array = array > threshold

    array_component = remove_all_but_the_largest_connected_component(array, [1], targetspacing)

    array_mask = array_component[0].astype(int)
    array_mask = binary_fill_holes(array_mask).astype(float)

    mask_img = sitk.GetImageFromArray(array_mask)
    mask_img.CopyInformation(img_obj)
    
    sitk.WriteImage(mask_img, datasavepath + 'mask/' + savename, True)
